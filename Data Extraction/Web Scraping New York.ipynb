# %% [markdown]
# ## Scraping Multiple Pages - New York

# %% [markdown]
# #### Importing Libraries

# %%
from bs4 import BeautifulSoup
import requests
import urllib.parse
import pandas as pd

# %% [markdown]
# #### Scraping the data

# %%
address = []
bedrooms = []
bathrooms = []
sqft = []
year_built = []
parking = []
pool = []
price = []

# Url part I
url_1 = 'https://www.trulia.com'

for i in range(1, 26):
    
    #website
    www = 'https://www.trulia.com/NY/New_York/' +str(i) +'_p/'
    
    #requests
    response = requests.get(www)
    
    # soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    #result container
    result_container = soup.find_all('li', {'class':'SearchResultsList__WideCell-b7y9ki-2'})
    
    #update results
    results_update = []
    
    # only results with attribute 'data-testeid'
    for r in result_container:
        if r.has_attr('data-testid'):
            results_update.append(r)
        
    #relative url
    relative_url = []
    
    #loop through results
    for i in results_update:
        for j in i.find_all('div', {'data-testid':'property-card-details'}):
            relative_url.append(j.find('a').get('href'))
            
    #empty list url_joined
    url_joined = []

    for i in relative_url:
        url_joined.append(urllib.parse.urljoin(url_1, i))
        
       
    # loop through all joined links
    for i in url_joined:
        response = requests.get(i)

        #create soup object
        soup = BeautifulSoup(response.content, 'html.parser')

        #address
        try:
            address.append(soup.find('span', {'data-testid':'home-details-summary-headline'}).get_text())
        except:
            address.append('')

        #bedrooms
        try:
            bedrooms.append(soup.find('li', {'data-testid':'bed'}).get_text())
        except:
            bedrooms.append('')

        #bathrooms
        try:
            bathrooms.append(soup.find('li', {'data-testid':'bath'}).get_text())
        except:
            bathrooms.append('')

        #sqft
        try:
            sqft.append(soup.find('li', {'data-testid':'floor'}).get_text())
        except:
            sqft.append('')

        #year built
        try:
            year_built.append(soup.find('div', string='Year Built').findNext('div').get_text())
        except:
            year_built.append('')

         #parking
        try:
            parking.append(soup.find('div', string='Parking').findNext('div').get_text())
        except:
            parking.append('')

         #pool
        try:
            pool.append(soup.find('div', string='Pool').findNext('div').get_text())
        except:
            pool.append('')

         #price
        try:
            price.append(soup.find('h3', {'data-testid':'on-market-price-details'}).get_text())
        except:
            price.append('')

        #creating a dictionary with the results
        output = {'Address': address, 'Bedrooms':bedrooms, 'Bathrooms': bathrooms, 'Area': sqft, 'Year Built': year_built,
                 'Parking': parking, 'Pool': pool, 'Price': price}

# %%
df = pd.DataFrame(output)
df
# Out:
#                      Address Bedrooms Bathrooms  ...  Parking  Pool         Price
# 0         303 E 57th St #32B   2 Beds   3 Baths  ...  No Info  Pool      $329,000
# 1          2239 Troy Ave #5N   2 Beds    1 Bath  ...  No Info            $199,000
# 2    432 Park Ave #PENTHOUSE   6 Beds   9 Baths  ...  No Info  Pool  $169,000,000
# 3         100 W 57th St #19M   Studio    1 Bath  ...  No Info            $119,000
# 4              8829 183rd St   3 Beds   2 Baths  ...   Garage    No      $250,000
# ..                       ...      ...       ...  ...      ...   ...           ...
# 995       390 W End Ave #5KN   2 Beds   2 Baths  ...  No Info          $3,500,000
# 996       629 Kappock St #5A   2 Beds    1 Bath  ...  No Info            $249,000
# 997           163-37 15th Dr   4 Beds   2 Baths  ...   Garage    No    $1,088,000
# 998           85-38 105th St   5 Beds   4 Baths  ...  No Info    No      $899,900
# 999      113-14 72nd Rd #6-K   2 Beds    1 Bath  ...  No Info            $549,000
#
# [1000 rows x 8 columns]

# %%
df['Location'] = 'New York'
df
# Out:
#                      Address Bedrooms Bathrooms  ...  Pool         Price  Location
# 0         303 E 57th St #32B   2 Beds   3 Baths  ...  Pool      $329,000  New York
# 1          2239 Troy Ave #5N   2 Beds    1 Bath  ...            $199,000  New York
# 2    432 Park Ave #PENTHOUSE   6 Beds   9 Baths  ...  Pool  $169,000,000  New York
# 3         100 W 57th St #19M   Studio    1 Bath  ...            $119,000  New York
# 4              8829 183rd St   3 Beds   2 Baths  ...    No      $250,000  New York
# ..                       ...      ...       ...  ...   ...           ...       ...
# 995       390 W End Ave #5KN   2 Beds   2 Baths  ...          $3,500,000  New York
# 996       629 Kappock St #5A   2 Beds    1 Bath  ...            $249,000  New York
# 997           163-37 15th Dr   4 Beds   2 Baths  ...    No    $1,088,000  New York
# 998           85-38 105th St   5 Beds   4 Baths  ...    No      $899,900  New York
# 999      113-14 72nd Rd #6-K   2 Beds    1 Bath  ...            $549,000  New York
#
# [1000 rows x 9 columns]

# %%
df.to_csv('df_new_york.csv', index=False)
