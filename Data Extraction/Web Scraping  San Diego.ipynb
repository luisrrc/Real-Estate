# %% [markdown]
# ## 1) Importing Libraries

# %%
from bs4 import BeautifulSoup
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import pandas as pd

# %% [markdown]
# ## 2) HTTP Request

# %% [markdown]
# #### a) Storing the website:

# %%
url = 'https://www.trulia.com/CA/San_Diego/'

# %% [markdown]
# #### b) Get Request:

# %% [markdown]
# session = requests.Session()
# retry = Retry(connect=3, backoff_factor=0.5)
# adapter = HTTPAdapter(max_retries=retry)
# session.mount('http://', adapter)
# session.mount('https://', adapter)
#
# session.get(url)

# %%
response = requests.get(url)

# %% [markdown]
# #### c) Status Code:

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ## 3) Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><script>
#             window.__uspapi = function(command, version, callback) {
#               try {
#                 if (command === 'getUSPData') {
#                   var cookies = document.cookie.split(';');
#                   for (var i = 0; i < cookies.length; i++) {
#                     var cookie = cookies[i];
#                     var separatorIndex = cookie.indexOf('=');
#                     separatorIndex = separatorIndex < 0 ? cookie.length : separatorIndex;
#                     var cookie_name = decodeURIComponent(cookie.slice(0, separatorIndex).replace(/^\s+/, ''));
#                     if (cookie_name === 'usprivacy') {
#                       var uspString = decodeURIComponent(cookie.slice(separatorIndex + 1));
#                       callback({ version: version, uspString: uspString }, true);
#                       return;
#                     }
#                   }
#                 }
#               } catch (ex) {
#                 console.error(ex);
#               }
#               callback(null, false);
#             }
#
#             window.addEventListener('message', function(event) {
#               if (event && event.data && event.data.__uspapiCall
#                 && event.source && event.source.postMessage
#               ) {
#                 window.__uspapi(
#                   event.data.__uspapiCall.command,
#                   event.data.__uspapiCall.version,
#                   function(data, success) {
#                     event.source.postMessage({
#                       __uspapiReturn: {
#                         returnValue: data,
#                         success: success,
#                         callId: event.data.__uspapiCall.callId
#                       }
#                     });
#                   }
#                 );
#               }
#             }, false);
#           </script><script>
#           window.trulia = window.trulia || {};
#           trulia.analytics = trulia.analytics || {};
#           trulia.analytics.automaticTrackState = false;
#         </script><style data-styled="" data-styled-version="5.1.1">.eIkmHi{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g1[id="MediaBlock__MediaContainer-skmvlj-0"]{content:"eIkmHi,"}/*!sc*/
# .gnreBg{margin:0 4px;}/*!sc*/
# .gnreBg:last-child{margin-right:0;}/*!sc*/
# .gnreBg:first-child{margin-left:0;}/*!sc*/
# .dwmuOU{margin:0 8px;}/*!sc*/
# .dwmuOU:last-child{margin-right:0;}/*!sc*/
# .dwmuOU:first-child{margin-left:0;}/*!sc*/
# .jNJnVO{margin:0 2px;}/*!sc*/
# .jNJnVO:last-child{margin-right:0;}/*!sc*/
# .jNJnVO:first-child{margin-left:0;}/*!sc*/
# .BVZzV{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;width:100%;margin:0 8px;}/*!sc*/
# .BVZzV:last-child{margin-right:0;}/*!sc*/
# .BVZzV:first-child{margin-left:0;}/*!sc*/
# .edhurL{margin:0 8px;overflow:hidden;}/*!sc*/
# .edhurL:last-child{margin-right:0;}/*!sc*/
# .edhurL:first-child{margin-left:0;}/*!sc*/
# .qjlKt{margin:0 2px;overflow:hidden;}/*!sc*/
# .qjlKt:last-child{margin-right:0;}/*!sc*/
# .qjlKt:first-child{margin-left:0;}/*!sc*/
# data-styled.g2[id="MediaBlock__MediaContent-skmvlj-1"]{content:"gnreBg,dwmuOU,jNJnVO,BVZzV,edhurL,qjlKt,"}/*!sc*/
# .cAsKxs{width:16px !important;height:16px !important;display:inline-block;font-size:0;}/*!sc*/
# .cAsKxs .svg{width:16px;}/*!sc*/
# .cAsKxs .svg{height:16px;}/*!sc*/
# .cAsKxs path{fill:rgb(107,119,128);}/*!sc*/
# .hnYFju{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .hnYFju .svg{width:24px;}/*!sc*/
# .hnYFju .svg{height:24px;}/*!sc*/
# .hnYFju path{fill:rgb(255,255,255);}/*!sc*/
# .jlplot{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .jlplot .svg{width:24px;}/*!sc*/
# .jlplot .svg{height:24px;}/*!sc*/
# .jlplot path{fill:rgb(0,120,130);}/*!sc*/
# .bXOPul{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .bXOPul .svg{width:24px;}/*!sc*/
# .bXOPul .svg{height:24px;}/*!sc*/
# .bXOPul path{fill:rgb(59,65,68);}/*!sc*/
# .iemARF{width:16px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .iemARF .svg{width:16px;}/*!sc*/
# .iemARF .svg{height:24px;}/*!sc*/
# .iemARF path{fill:rgb(0,120,130);}/*!sc*/
# .csIvyu{width:20px !important;height:20px !important;display:inline-block;font-size:0;}/*!sc*/
# .csIvyu .svg{width:20px;}/*!sc*/
# .csIvyu .svg{height:20px;}/*!sc*/
# .csIvyu path{fill:rgb(0,133,69);}/*!sc*/
# .dEvZww{width:20px !important;height:20px !important;display:inline-block;font-size:0;}/*!sc*/
# .dEvZww .svg{width:20px;}/*!sc*/
# .dEvZww .svg{height:20px;}/*!sc*/
# .dEvZww path{fill:rgb(217,60,35);}/*!sc*/
# .ijNWVp{width:20px !important;height:20px !important;display:inline-block;font-size:0;}/*!sc*/
# .ijNWVp .svg{width:20px;}/*!sc*/
# .ijNWVp .svg{height:20px;}/*!sc*/
# .ijNWVp path{fill:rgb(0,120,130);}/*!sc*/
# .ckNPAJ{width:16px !important;height:16px !important;display:inline-block;font-size:0;}/*!sc*/
# .ckNPAJ .svg{width:16px;}/*!sc*/
# .ckNPAJ .svg{height:16px;}/*!sc*/
# .ckNPAJ path{fill:rgb(0,120,130);}/*!sc*/
# .jfYGaR{width:20px !important;height:20px !important;display:inline-block;font-size:0;}/*!sc*/
# .jfYGaR .svg{width:20px;}/*!sc*/
# .jfYGaR .svg{height:20px;}/*!sc*/
# .jfYGaR path{fill:rgb(59,65,68);}/*!sc*/
# data-styled.g3[id="getUiSvgContainer__SvgContainer-sc-1cdn1ln-0"]{content:"cAsKxs,hnYFju,jlplot,bXOPul,iemARF,csIvyu,dEvZww,ijNWVp,ckNPAJ,jfYGaR,"}/*!sc*/
# .dROcJl{display:none;}/*!sc*/
# .bsjsJO{display:block;}/*!sc*/
# .jqAYVe{display:block;border-style:solid !important;border-color:rgb(205,209,212);border-width:0 0 1px 0;}/*!sc*/
# .bhkWRs{display:block;}/*!sc*/
# @media (min-width:376px){.bhkWRs{display:block;}}/*!sc*/
# @media (min-width:570px){.bhkWRs{display:block;}}/*!sc*/
# @media (min-width:768px){.bhkWRs{display:none;}}/*!sc*/
# @media (min-width:993px){.bhkWRs{display:none;}}/*!sc*/
# .fchmFc{display:none;}/*!sc*/
# @media (min-width:376px){.fchmFc{display:none;}}/*!sc*/
# @media (min-width:570px){.fchmFc{display:none;}}/*!sc*/
# @media (min-width:768px){.fchmFc{display:block;}}/*!sc*/
# @media (min-width:993px){.fchmFc{display:none;}}/*!sc*/
# .khumPA{display:none;}/*!sc*/
# @media (min-width:376px){.khumPA{display:none;}}/*!sc*/
# @media (min-width:570px){.khumPA{display:none;}}/*!sc*/
# @media (min-width:768px){.khumPA{display:none;}}/*!sc*/
# @media (min-width:993px){.khumPA{display:block;}}/*!sc*/
# .cPZGSD{display:inline-block;display:inline-block;}/*!sc*/
# data-styled.g4[id="Box__BoxElement-sc-1f5rw0h-0"]{content:"dROcJl,bsjsJO,jqAYVe,bhkWRs,fchmFc,khumPA,cPZGSD,"}/*!sc*/
# .fAXlbl{cursor:pointer;display:inline;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# .fAXlbl[role='button']:active{outline:none;box-shadow:0 0 0 1px rgb(107,119,128);}/*!sc*/
# .fAXlbl:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .erxzVp{cursor:pointer;display:inline-block;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# .erxzVp[role='button']:active{outline:none;box-shadow:0 0 0 1px rgb(107,119,128);}/*!sc*/
# .erxzVp:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g5[id="BoxButton-sc-12vrxun-0"]{content:"fAXlbl,erxzVp,"}/*!sc*/
# .gCjLgA{font-weight:bold;}/*!sc*/
# .bxzLaH{font-size:14px;line-height:1.43;}/*!sc*/
# .bxzLaH .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;width:20.02px;}/*!sc*/
# .kRmhGt{color:rgb(0,120,130);}/*!sc*/
# data-styled.g7[id="Text__TextBase-sc-1cait9d-0"]{content:"gCjLgA,dujbAG,bxzLaH,kRmhGt,"}/*!sc*/
# .ilVROc{font-weight:bold;font-size:20px;line-height:1.2;}/*!sc*/
# .ilVROc .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .fkSzsq{color:rgb(0,120,130);}/*!sc*/
# .keMYfJ{font-weight:bold;font-size:20px;line-height:1.2;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .keMYfJ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .bjqKkI{font-size:16px;line-height:1.5;}/*!sc*/
# .bjqKkI .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .dZyoXR{font-size:16px;line-height:1.5;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .dZyoXR .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .ccZuZv{color:rgb(107,119,128);font-size:10px;line-height:1.6;}/*!sc*/
# .ccZuZv .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:16px;width:16px;}/*!sc*/
# .uyZVK{font-weight:bold;font-size:14px;line-height:1.43;}/*!sc*/
# .uyZVK .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;width:20.02px;}/*!sc*/
# .RBSGf{color:rgb(107,119,128);font-size:12px;line-height:1.33;}/*!sc*/
# .RBSGf .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:15.96px;width:15.96px;}/*!sc*/
# .kgxmNH{color:rgb(107,119,128);}/*!sc*/
# .gA-DbwZ{font-weight:bold;font-size:14px;line-height:1.43;}/*!sc*/
# @media (min-width:376px){.gA-DbwZ{font-size:14px;}}/*!sc*/
# @media (min-width:570px){.gA-DbwZ{font-size:14px;}}/*!sc*/
# @media (min-width:768px){.gA-DbwZ{font-size:16px;}}/*!sc*/
# @media (min-width:376px){.gA-DbwZ{line-height:1.43;}}/*!sc*/
# @media (min-width:570px){.gA-DbwZ{line-height:1.43;}}/*!sc*/
# @media (min-width:768px){.gA-DbwZ{line-height:1.5;}}/*!sc*/
# .gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;width:20.02px;}/*!sc*/
# @media (min-width:376px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;}}/*!sc*/
# @media (min-width:570px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;}}/*!sc*/
# @media (min-width:768px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;}}/*!sc*/
# @media (min-width:376px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:20.02px;}}/*!sc*/
# @media (min-width:570px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:20.02px;}}/*!sc*/
# @media (min-width:768px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:24px;}}/*!sc*/
# .cTGlQX{font-weight:bold;}/*!sc*/
# data-styled.g9[id="Text__TextContainerBase-sc-1cait9d-1"]{content:"ilVROc,oVGDp,fkSzsq,keMYfJ,bjqKkI,dZyoXR,ccZuZv,uyZVK,RBSGf,kgxmNH,gA-DbwZ,cTGlQX,"}/*!sc*/
# .gijRfk{padding:8px 16px 8px 16px;}/*!sc*/
# .kGavLk{padding:0 8px 0 0;}/*!sc*/
# .hMDWQm{padding:0 0 0 2px;}/*!sc*/
# .dZDbka{padding:4px 2px 0 0;}/*!sc*/
# .kRVDgw{padding:8px 0 0 0;}/*!sc*/
# .kGaqTU{padding:0 4px 0 0;}/*!sc*/
# .fcYWAF{padding:0 0 32px 0;}/*!sc*/
# .dtoUNs{padding:0 0 0 0;}/*!sc*/
# .kftGdI{padding:16px 0 16px 0;}/*!sc*/
# data-styled.g10[id="Padding-sc-1tki7vp-0"]{content:"gijRfk,kGavLk,hMDWQm,dZDbka,kRVDgw,kGaqTU,fcYWAF,dtoUNs,kftGdI,"}/*!sc*/
# .bPNugb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:auto;-webkit-overflow-scrolling:touch;}/*!sc*/
# @media (max-width:47.9375em){.bPNugb{display:block;}}/*!sc*/
# data-styled.g12[id="FlexContainers__Rows-zvngfq-0"]{content:"bPNugb,"}/*!sc*/
# .eCjeDf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# data-styled.g14[id="FlexContainers__Columns-zvngfq-2"]{content:"eCjeDf,"}/*!sc*/
# .kRfxNx{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;-webkit-text-decoration:none;text-decoration:none;font-size:16px;line-height:1.5;padding:8px 16px;outline:none;}/*!sc*/
# .kRfxNx path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .kRfxNx .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .kRfxNx::-moz-focus-inner{border:0;}/*!sc*/
# .kRfxNx[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .kRfxNx:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g22[id="ButtonBase-sc-14ooajz-0"]{content:"kRfxNx,"}/*!sc*/
# .iSYPov{line-height:1;color:inherit;}/*!sc*/
# .iSYPov:hover,.iSYPov:focus{color:rgb(0,120,130);}/*!sc*/
# .iSYPov:hover path,.iSYPov:focus path{fill:rgb(0,120,130);}/*!sc*/
# .jPioDE{line-height:1;color:inherit;}/*!sc*/
# data-styled.g30[id="UiButton-r41csk-0"]{content:"iSYPov,jPioDE,"}/*!sc*/
# .iLsXMy{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;-webkit-text-decoration:none;text-decoration:none;font-size:16px;line-height:1.5;padding:8px 16px;outline:none;color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:rgb(205,209,212);}/*!sc*/
# .iLsXMy path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .iLsXMy .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .iLsXMy::-moz-focus-inner{border:0;}/*!sc*/
# .iLsXMy[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .iLsXMy:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .iLsXMy:hover,.iLsXMy[class~='hover']{color:rgb(59,65,68);background-color:rgb(232,233,234);border-color:transparent;}/*!sc*/
# .iLsXMy[class~='focus'],.iLsXMy:focus{color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:rgb(107,119,128);outline:none;}/*!sc*/
# .iLsXMy[class~='focus']:focus-visible,.iLsXMy:focus:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .iLsXMy[class~='active'],.iLsXMy:active{color:rgb(255,255,255);background-color:rgb(107,119,128);border-color:transparent;}/*!sc*/
# .iLsXMy[class~='active'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.iLsXMy:active .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(255,255,255);}/*!sc*/
# .iLsXMy[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);}/*!sc*/
# .iLsXMy[disabled] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(205,209,212);}/*!sc*/
# data-styled.g34[id="Button-sc-1ea9wz-0"]{content:"iLsXMy,"}/*!sc*/
# .bQSVOQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:-8px;margin-right:-8px;margin-top:-16px;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# .bQSVOQ > .Grid__CellBox-sc-144isrp-0{border-style:solid;border-color:transparent;border-width:16px 8px 0px 8px;}/*!sc*/
# data-styled.g54[id="Grid__GridContainer-sc-144isrp-1"]{content:"bQSVOQ,"}/*!sc*/
# .hPjFaC{object-fit:cover;width:100%;height:100%;}/*!sc*/
# .gBlKLF{width:16px;height:16px;}/*!sc*/
# .cOExqt{width:20px;height:20px;}/*!sc*/
# .emFnwq{width:auto;height:100%;}/*!sc*/
# data-styled.g56[id="Image__ImageContainer-sc-1motiir-0"]{content:"hPjFaC,gBlKLF,cOExqt,emFnwq,"}/*!sc*/
# .eWkDYx{width:70px;height:24px;display:inline-block;line-height:0;}/*!sc*/
# .eWkDYx .svg{width:70px;}/*!sc*/
# .eWkDYx .svg{height:24px;}/*!sc*/
# data-styled.g58[id="getSvgContainer__SvgContainer-sc-9w90nz-0"]{content:"eWkDYx,"}/*!sc*/
# .cKFaMj{height:20px;}/*!sc*/
# .cKFaMj .svg{height:20px;}/*!sc*/
# data-styled.g59[id="getSvgContainer__StyledImage-sc-9w90nz-1"]{content:"cKFaMj,"}/*!sc*/
# .gSLuwD{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .gSLuwD:hover{-webkit-text-decoration:underline;text-decoration:underline;color:rgb(0,69,75);}/*!sc*/
# data-styled.g60[id="Anchor__StyledText-sc-5lya7g-0"]{content:"gSLuwD,"}/*!sc*/
# .euBOac{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .euBOac:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .gLFHbk{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .gLFHbk:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g61[id="Anchor__StyledAnchor-sc-5lya7g-1"]{content:"euBOac,gLFHbk,"}/*!sc*/
# .eAlroL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:64px;margin:0;padding:0 16px 0 16px;padding:0 calc(16px + env(safe-area-inset-right)) 0 calc(16px + env(safe-area-inset-left));background-color:rgb(255,255,255);position:relative;z-index:100;font-size:15px;border-bottom:1px solid rgb(232,233,234);}/*!sc*/
# @media (max-width:62em){.eAlroL{padding:0 12px;}}/*!sc*/
# data-styled.g65[id="Navbar__Nav-sky7mr-0"]{content:"eAlroL,"}/*!sc*/
# .ZwySm{margin-left:16px;padding:0 4px;background-color:rgb(255,255,255);}/*!sc*/
# @media (max-width:62em){.ZwySm{margin-right:-10px;margin-left:2px;}}/*!sc*/
# data-styled.g66[id="Navbar__NavbarMobileMenuToggle-sky7mr-1"]{content:"ZwySm,"}/*!sc*/
# .lmeUPp{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding:16px 24px 16px 0;}/*!sc*/
# @media (max-width:62em){.lmeUPp{padding:12px 12px 12px 6px;}}/*!sc*/
# data-styled.g67[id="Navbar__LogoContainer-sky7mr-2"]{content:"lmeUPp,"}/*!sc*/
# .kbckwe{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justift-content:center;-ms-flex-pack:center;justift-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:100%;}/*!sc*/
# data-styled.g69[id="Navbar__IconContainer-sky7mr-4"]{content:"kbckwe,"}/*!sc*/
# .iMHbRw{color:rgb(59,65,68);-webkit-transition:background 0.15s ease-in-out;transition:background 0.15s ease-in-out;position:relative;}/*!sc*/
# .iMHbRw > a,.iMHbRw > span,.iMHbRw > button:not(.Button-sc-1ea9wz-0){cursor:pointer;padding:8px 16px 8px 16px;color:rgb(59,65,68);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:8px;background-color:transparent;}/*!sc*/
# .iMHbRw > a:focus svg path,.iMHbRw > span:focus svg path,.iMHbRw > button:not(.Button-sc-1ea9wz-0):focus svg path{fill:rgb(59,65,68);}/*!sc*/
# .iMHbRw svg{margin-top:-1px;}/*!sc*/
# .iMHbRw > span{cursor:default;}/*!sc*/
# .iMHbRw:hover > a,.iMHbRw:hover > span,.iMHbRw:hover > button:not(.Button-sc-1ea9wz-0){color:rgb(255,255,255);background-color:rgb(0,120,130);}/*!sc*/
# .iMHbRw:hover > a svg path,.iMHbRw:hover > span svg path,.iMHbRw:hover > button:not(.Button-sc-1ea9wz-0) svg path{fill:rgb(255,255,255);}/*!sc*/
# .iMHbRw:hover > ul{display:block;}/*!sc*/
# .iMHbRw ul{display:none;position:absolute;top:45px;background:rgb(255,255,255);border-radius:4px;box-shadow:0 2px 4px 0 rgba(59,65,68,0.5);padding:4px 0;}/*!sc*/
# .iMHbRw ul a,.iMHbRw ul button{color:rgb(59,65,68);white-space:nowrap;display:block;}/*!sc*/
# .iMHbRw ul a:hover,.iMHbRw ul button:hover{color:rgb(59,65,68);background-color:rgb(232,233,234);}/*!sc*/
# .iMHbRw ul::before{display:block;position:absolute;content:'';width:100%;height:15px;top:-15px;}/*!sc*/
# @media (max-width:62em){.iMHbRw{display:none;}}/*!sc*/
# data-styled.g75[id="NavbarItem__StyledNavbarItem-sc-1kjsgse-0"]{content:"iMHbRw,"}/*!sc*/
# .jvZEPV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:4px;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;}/*!sc*/
# @media (min-width:1060px){}/*!sc*/
# @media (min-width:1240px){}/*!sc*/
# data-styled.g77[id="NavbarSection-gp9p9l-0"]{content:"jvZEPV,"}/*!sc*/
# .fgHPbp{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;-webkit-text-decoration:none;text-decoration:none;font-size:16px;line-height:1.5;padding:8px 16px;outline:none;color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:transparent;}/*!sc*/
# .fgHPbp path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .fgHPbp .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .fgHPbp::-moz-focus-inner{border:0;}/*!sc*/
# .fgHPbp[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .fgHPbp:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .fgHPbp .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(59,65,68);}/*!sc*/
# .fgHPbp[class~='hover'],.fgHPbp:hover{color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transprant;}/*!sc*/
# .fgHPbp[class~='hover'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.fgHPbp:hover .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(255,255,255);}/*!sc*/
# .fgHPbp[class~='focus'],.fgHPbp:focus{color:rgb(0,120,130);border-color:rgb(0,120,130);}/*!sc*/
# .fgHPbp[class~='focus'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.fgHPbp:focus .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(0,120,130);}/*!sc*/
# .fgHPbp[class~='active'],.fgHPbp:active{color:rgb(59,65,68);background-color:rgb(232,233,234);border-color:transparent;box-shadow:none;}/*!sc*/
# .fgHPbp[class~='active'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.fgHPbp:active .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(59,65,68);}/*!sc*/
# .fgHPbp[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);box-shadow:none;}/*!sc*/
# .fgHPbp[disabled] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(205,209,212);}/*!sc*/
# data-styled.g80[id="GlobalNavigationButton-x0gdrd-0"]{content:"fgHPbp,"}/*!sc*/
# .gQGHnr li{display:inline-block;border-style:none;margin-right:8px;}/*!sc*/
# .gQGHnr li:last-child{margin:0;}/*!sc*/
# data-styled.g81[id="List__ListContainer-sc-8uj508-0"]{content:"ljHPkT,gQGHnr,"}/*!sc*/
# .dwoxWy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:0;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;-webkit-flex:0 1 420px;-ms-flex:0 1 420px;flex:0 1 420px;}/*!sc*/
# @media (min-width:1060px){}/*!sc*/
# @media (min-width:1240px){}/*!sc*/
# @media (max-width:62em){.dwoxWy{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;width:100%;}}/*!sc*/
# data-styled.g87[id="NavbarContainer__SearchBarSection-sc-15svuwa-5"]{content:"dwoxWy,"}/*!sc*/
# @media (max-width:1240px){.pFuxB{display:none;}}/*!sc*/
# @media (max-width:1060px){.pFuxB{display:none;}}/*!sc*/
# data-styled.g88[id="NavbarContainer__NavLinkItem-sc-15svuwa-6"]{content:"pFuxB,"}/*!sc*/
# .cHCUKt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;}/*!sc*/
# @media (max-width:62em){.cHCUKt{display:none;}}/*!sc*/
# data-styled.g89[id="NavbarContainer__UserButtonsItem-sc-15svuwa-7"]{content:"cHCUKt,"}/*!sc*/
# .fZJkX{border:1px solid rgb(245,246,247);border-radius:8px;background-color:rgb(245,246,247);padding:8px 64px 8px 16px;color:rgb(59,65,68);font-size:16px;line-height:1.5;width:100%;height:42px;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;display:inline-block;-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# .fZJkX.react-autosuggest__input--open{border:1px solid rgb(245,246,247);border-radius:8px;border-bottom-left-radius:0px;border-bottom-right-radius:0px;border-bottom:none;}/*!sc*/
# .fZJkX .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .fZJkX::-webkit-input-placeholder{color:#606F76;}/*!sc*/
# .fZJkX::-moz-placeholder{color:#606F76;}/*!sc*/
# .fZJkX:-ms-input-placeholder{color:#606F76;}/*!sc*/
# .fZJkX::placeholder{color:#606F76;}/*!sc*/
# .fZJkX[placeholder]{text-overflow:ellipsis;}/*!sc*/
# .fZJkX::-ms-clear{display:none;}/*!sc*/
# .fZJkX:focus{border-color:rgb(205,209,212);background-color:rgb(255,255,255);outline:none;}/*!sc*/
# .fZJkX::-webkit-search-cancel-button{display:none;}/*!sc*/
# .fZJkX:focus{padding-right:80px;}/*!sc*/
# data-styled.g93[id="LocationAutosuggestInput__Input-sc-789ttj-0"]{content:"fZJkX,"}/*!sc*/
# .cFovxO{position:relative;}/*!sc*/
# data-styled.g94[id="LocationAutosuggestInput__InputContainer-sc-789ttj-1"]{content:"cFovxO,"}/*!sc*/
# .gNheLz{cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:absolute;right:48px;top:0;height:100%;padding:12px;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# input:not(:focus) + .gNheLz{pointer-events:none;opacity:0;}/*!sc*/
# input:not(:focus) + .gNheLz:focus{pointer-events:all;opacity:1;}/*!sc*/
# .gNheLz:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g95[id="LocationAutosuggestInput__RightInnerIcon-sc-789ttj-2"]{content:"gNheLz,"}/*!sc*/
# .kIJIQK{cursor:pointer;display:block;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;position:absolute;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;right:0;top:0;height:100%;min-width:42px;cursor:pointer;background-color:rgb(217,60,35);padding:9px 12px;border-bottom-right-radius:8px;border-top-right-radius:8px;-webkit-transition:background-color 0.15s ease;transition:background-color 0.15s ease;}/*!sc*/
# .kIJIQK[role='button']:active{outline:none;box-shadow:0 0 0 1px rgb(107,119,128);}/*!sc*/
# .kIJIQK:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .react-autosuggest__input--open ~ .kIJIQK{border-bottom-right-radius:0;}/*!sc*/
# .kIJIQK:hover{background-color:rgb(156,17,20);}/*!sc*/
# .kIJIQK.focus-visible:not(:focus-visible){box-shadow:none;}/*!sc*/
# data-styled.g96[id="LocationAutosuggestInput__RightIcon-sc-789ttj-3"]{content:"kIJIQK,"}/*!sc*/
# .lcWvKj{border:1px solid rgb(205,209,212);border-bottom-right-radius:8px;border-bottom-left-radius:8px;position:absolute;width:100%;background:white;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;max-height:50vh;overflow:auto;-webkit-overflow-scrolling:touch;opacity:0;}/*!sc*/
# data-styled.g97[id="LocationAutosuggestDrodown__LocationAutosuggestDropdown-sc-22jd4l-0"]{content:"lcWvKj,"}/*!sc*/
# .kIXuPW{position:relative;width:100%;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;}/*!sc*/
# .kIXuPW .react-autosuggest__suggestion--first .LocationAutosuggestDrodown__ItemContainer-sc-22jd4l-2{border:none;}/*!sc*/
# .kIXuPW .react-autosuggest__section-title + .react-autosuggest__suggestions-list > .react-autosuggest__suggestion--first .LocationAutosuggestDrodown__ItemContainer-sc-22jd4l-2{border-top:none;}/*!sc*/
# data-styled.g100[id="LocationAutosuggestDrodown__LocationAutosuggestBoxContainer-sc-22jd4l-3"]{content:"kIXuPW,"}/*!sc*/
# .liYvlm{color:rgb(59,65,68);}/*!sc*/
# .liYvlm:hover{color:rgb(0,120,130);}/*!sc*/
# @media (max-width:23.4375em){.liYvlm{line-height:25px;}}/*!sc*/
# data-styled.g107[id="FooterAnchor-sc-1qyjqke-0"]{content:"liYvlm,"}/*!sc*/
# .eDgeeY{padding:16px env(safe-area-inset-right) env(safe-area-inset-bottom) env(safe-area-inset-left);font-size:10px;line-height:1.6;}/*!sc*/
# .eDgeeY .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:16px;width:16px;}/*!sc*/
# data-styled.g108[id="Copyright__Container-r29r4j-0"]{content:"eDgeeY,"}/*!sc*/
# .dCpGms{padding:16px env(safe-area-inset-right) 16px env(safe-area-inset-left);font-size:12px;line-height:1.33;}/*!sc*/
# .dCpGms .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:15.96px;width:15.96px;}/*!sc*/
# @media (max-width:23.4375em){.dCpGms{line-height:22px;}}/*!sc*/
# data-styled.g109[id="Accessibility__Container-vmfiy3-0"]{content:"dCpGms,"}/*!sc*/
# .ivICeq{padding:0;font-size:12px;line-height:1.33;}/*!sc*/
# .ivICeq .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:15.96px;width:15.96px;}/*!sc*/
# data-styled.g110[id="Footer__FooterContainer-h25adx-0"]{content:"ivICeq,"}/*!sc*/
# @media (max-width:47.9375em){.fLjkrG{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.fLjkrG::after{content:'';width:4px;height:4px;border-radius:50%;background-color:currentColor;margin:0 4px 0;}.fLjkrG:last-child:after{display:none;}}/*!sc*/
# @media (max-width:47.9375em){.iXDUHN{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.iXDUHN::after{content:'';width:4px;height:4px;border-radius:50%;background-color:currentColor;margin:0 4px 0;}.iXDUHN:last-child:after{display:none;}}/*!sc*/
# .iXDUHN:after{display:none;}/*!sc*/
# .etPKim{display:none;}/*!sc*/
# data-styled.g111[id="LinkColumn__ListItem-sc-18qnqbg-0"]{content:"fLjkrG,iXDUHN,etPKim,"}/*!sc*/
# .chUtxH{color:rgb(59,65,68);-webkit-text-decoration:none;text-decoration:none;padding:2px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .chUtxH:hover{color:rgb(0,120,130);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .chUtxH div{padding-right:24px;}/*!sc*/
# @media (max-width:23.4375em){.chUtxH{line-height:25px;}}/*!sc*/
# data-styled.g112[id="LinkColumn__Link-sc-18qnqbg-1"]{content:"chUtxH,"}/*!sc*/
# .eiMzua{padding:32px 0 8px 0;}/*!sc*/
# @media (min-width:48em){.eiMzua{padding:2px 0;}}/*!sc*/
# .eiMzua a{color:rgb(59,65,68);-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .eiMzua a:hover{color:rgb(0,120,130);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g113[id="LinkColumn__LinkColumnHeading-sc-18qnqbg-2"]{content:"eiMzua,"}/*!sc*/
# .fGQGPu{position:relative;color:rgb(0,173,187);font-size:12px;line-height:1.33;padding:0;}/*!sc*/
# .fGQGPu .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:15.96px;width:15.96px;}/*!sc*/
# data-styled.g114[id="LinkColumn__ToggleMenuButton-sc-18qnqbg-3"]{content:"fGQGPu,"}/*!sc*/
# .gfYCGU{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;margin-left:8px;}/*!sc*/
# .gfYCGU:first-child{margin-left:0;}/*!sc*/
# @media (max-width:47.9375em){.gfYCGU{-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;margin-left:0;}}/*!sc*/
# data-styled.g115[id="LinkColumn__Column-sc-18qnqbg-4"]{content:"gfYCGU,"}/*!sc*/
# .dyUsOb{padding:0 env(safe-area-inset-right) 0 env(safe-area-inset-left);}/*!sc*/
# data-styled.g116[id="NavigationSecondary__Container-sc-59f6ac-0"]{content:"dyUsOb,"}/*!sc*/
# .iagBDf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;padding:0 0 24px;}/*!sc*/
# @media (max-width:47.9375em){.iagBDf{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# data-styled.g117[id="NavigationSecondary__Inner-sc-59f6ac-1"]{content:"iagBDf,"}/*!sc*/
# .bmseOe{padding:0 env(safe-area-inset-right) 0 env(safe-area-inset-left);}/*!sc*/
# data-styled.g118[id="FooterLinkList__Container-yuht23-0"]{content:"bmseOe,"}/*!sc*/
# .fRcNIL{color:rgb(59,65,68);-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .fRcNIL:hover{color:rgb(0,120,130);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g119[id="FooterLinkList__CookiePreferenceLink-yuht23-1"]{content:"fRcNIL,"}/*!sc*/
# .gledEB{list-style:none;display:inline-block;margin:0;padding:16px 0 16px;}/*!sc*/
# .gledEB li{display:inline;}/*!sc*/
# .gledEB li + li::before{content:'';display:inline-block;vertical-align:middle;width:4px;height:4px;border-radius:50%;background-color:currentColor;margin:0 4px 2px;}/*!sc*/
# data-styled.g120[id="FooterLinkList__LinkList-yuht23-2"]{content:"gledEB,"}/*!sc*/
# .iVrQNM{background-color:rgb(255,255,255);border:1px solid rgb(232,233,234);border-radius:8px;padding:0;}/*!sc*/
# data-styled.g128[id="Card-qyhhuy-0"]{content:"iVrQNM,"}/*!sc*/
# .jOttt{color:rgb(0,120,130);background-color:rgb(255,255,255);border-color:rgb(0,173,187);}/*!sc*/
# .jOttt .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(0,120,130);}/*!sc*/
# .jOttt[class~='hover'],.jOttt:hover{color:rgb(0,120,130);background-color:rgb(224,247,248);border-color:rgb(0,120,130);}/*!sc*/
# .jOttt[class~='hover'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.jOttt:hover .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(0,120,130);}/*!sc*/
# .jOttt[class~='focus'],.jOttt:focus{color:rgb(0,120,130);background-color:rgb(255,255,255);border-color:rgb(0,120,130);}/*!sc*/
# .jOttt[class~='focus'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.jOttt:focus .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(0,120,130);}/*!sc*/
# .jOttt[class~='active'],.jOttt:active{color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transparent;}/*!sc*/
# .jOttt[class~='active'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.jOttt:active .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(255,255,255);}/*!sc*/
# .jOttt[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);}/*!sc*/
# .jOttt[disabled] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(205,209,212);}/*!sc*/
# data-styled.g135[id="SecondaryButton-sc-16u2mmq-0"]{content:"jOttt,"}/*!sc*/
# .cyuFDE{width:100%;display:inline-block;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;font-weight:bold;width:unset;border-radius:8px;background-color:rgb(255,255,255);-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;padding:8px;}/*!sc*/
# .cyuFDE:focus-within{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g147[id="Select__SelectContainer-sc-1l7enz0-0"]{content:"cyuFDE,"}/*!sc*/
# .hltsmt{position:absolute;opacity:0;width:100%;height:100%;top:0;left:0;right:0;bottom:0;cursor:pointer;-webkit-appearance:none;font-size:16px;line-height:1.5;}/*!sc*/
# .hltsmt .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# data-styled.g148[id="Select__NativeSelect-sc-1l7enz0-1"]{content:"hltsmt,"}/*!sc*/
# .hNEPJh{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}/*!sc*/
# .hNEPJh > button:focus,.hNEPJh a:focus{z-index:1;}/*!sc*/
# .hNEPJh > .ButtonBase-sc-14ooajz-0{margin:0;}/*!sc*/
# .hNEPJh > .ButtonBase-sc-14ooajz-0:not(:first-child){border-top-left-radius:0;border-bottom-left-radius:0;}/*!sc*/
# .hNEPJh > .ButtonBase-sc-14ooajz-0:not(:last-child){border-top-right-radius:0;border-bottom-right-radius:0;border-right:0;}/*!sc*/
# .hNEPJh > .ButtonBase-sc-14ooajz-0:focus{border-right:1px solid;}/*!sc*/
# .hNEPJh > .ButtonBase-sc-14ooajz-0:focus + .ButtonBase-sc-14ooajz-0{border-left:0;}/*!sc*/
# .hNEPJh > .PrimaryButton-sc-16zopmz-0:focus{border-right:1px solid;}/*!sc*/
# .hNEPJh > .PrimaryButton-sc-16zopmz-0:focus + .ButtonBase-sc-14ooajz-0{border-left:0;}/*!sc*/
# .hNEPJh > .PrimaryButton-sc-16zopmz-0:hover{border-right:1px solid;color:rgb(255,255,255);background-color:rgb(0,120,130);}/*!sc*/
# .hNEPJh > .PrimaryButton-sc-16zopmz-0:hover + .ButtonBase-sc-14ooajz-0{border-left:0;}/*!sc*/
# .hNEPJh > .PrimaryButton-sc-16zopmz-0:hover .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(255,255,255);}/*!sc*/
# .hNEPJh > .TertiaryButton-sc-1ve5gq4-0:focus{border-right:1px solid;}/*!sc*/
# .hNEPJh > .TertiaryButton-sc-1ve5gq4-0:focus + .ButtonBase-sc-14ooajz-0{border-left:0;}/*!sc*/
# .hNEPJh > .TertiaryButton-sc-1ve5gq4-0:hover{border-right:1px solid;color:rgb(255,255,255);background-color:rgb(217,60,35);}/*!sc*/
# .hNEPJh > .TertiaryButton-sc-1ve5gq4-0:hover + .ButtonBase-sc-14ooajz-0{border-left:0;}/*!sc*/
# .hNEPJh > .TertiaryButton-sc-1ve5gq4-0:hover .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(255,255,255);}/*!sc*/
# .hNEPJh > .PrimaryButton-sc-16zopmz-0 + .ButtonBase-sc-14ooajz-0,.hNEPJh > .TertiaryButton-sc-1ve5gq4-0 + .ButtonBase-sc-14ooajz-0,.hNEPJh > [enabled='1'] + .ButtonBase-sc-14ooajz-0{border-left-color:transparent;}/*!sc*/
# data-styled.g150[id="ButtonGroup-g55gjt-0"]{content:"hNEPJh,"}/*!sc*/
# .jKLoTy{position:relative;background-color:rgb(245,246,247);border-radius:8px;}/*!sc*/
# data-styled.g151[id="ButtonToggle__ButtonToggleContainer-xkit6c-0"]{content:"jKLoTy,"}/*!sc*/
# .xSdQe{position:relative;z-index:1;}/*!sc*/
# data-styled.g152[id="ButtonToggle__ButtonToggles-xkit6c-1"]{content:"xSdQe,"}/*!sc*/
# .wjvvt{border:1px solid transparent;background-color:transparent;margin:0;border-radius:8px;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;padding:8px 16px;padding:8px;font-size:14px;-webkit-tap-highlight-color:transparent;color:rgb(205,209,212);border:1px solid rgb(205,209,212);}/*!sc*/
# .wjvvt::-moz-focus-inner{border:0;}/*!sc*/
# .wjvvt[class~='focus'],.wjvvt:focus{outline:none;}/*!sc*/
# @media (min-width:476px){.wjvvt{padding:8px 16px;font-size:16px;}}/*!sc*/
# .bggOWZ{border:1px solid transparent;background-color:transparent;margin:0;border-radius:8px;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;padding:8px 16px;padding:8px;font-size:14px;-webkit-tap-highlight-color:transparent;color:rgb(205,209,212);border-width:1px;border-style:solid;border-color: rgb(205,209,212) rgb(205,209,212) rgb(205,209,212) transparent;position:relative;border-radius:0 8px 8px 0;}/*!sc*/
# .bggOWZ::-moz-focus-inner{border:0;}/*!sc*/
# .bggOWZ[class~='focus'],.bggOWZ:focus{outline:none;}/*!sc*/
# @media (min-width:476px){.bggOWZ{padding:8px 16px;font-size:16px;}}/*!sc*/
# .bggOWZ:before{content:'';position:absolute;border-width:1px 0 1px 0;border-style:solid;border-color:rgb(205,209,212);width:100%;height:100%;left:-10px;top:-1px;}/*!sc*/
# data-styled.g153[id="ButtonToggle__InativeButton-xkit6c-2"]{content:"wjvvt,bggOWZ,"}/*!sc*/
# .ioiqmz{border-radius:8px;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;padding:8px 16px;padding:8px;border-width:1px;border-style:solid;border-color:rgb(205,209,212);background-color:#fff;position:absolute;left:0;top:0;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;font-size:14px;height:39px;-webkit-transition:all 480ms ease-in;transition:all 480ms ease-in;display:none;}/*!sc*/
# .ioiqmz::-moz-focus-inner{border:0;}/*!sc*/
# .ioiqmz[class~='focus'],.ioiqmz:focus{outline:none;}/*!sc*/
# @media (min-width:476px){.ioiqmz{padding:8px 16px;font-size:16px;height:42px;}}/*!sc*/
# data-styled.g154[id="ButtonToggle__ActiveBar-xkit6c-3"]{content:"ioiqmz,"}/*!sc*/
# .juIvTV{cursor:pointer;position:relative;border:0;outline:none;}/*!sc*/
# data-styled.g155[id="ButtonToggle__MainLabel-xkit6c-4"]{content:"juIvTV,"}/*!sc*/
# .ePKvwf{padding-left:4px;font-weight:300;cursor:pointer;display:none;}/*!sc*/
# @media (min-width:375px){.ePKvwf{display:inline;}}/*!sc*/
# data-styled.g156[id="ButtonToggle__SubLabel-xkit6c-5"]{content:"ePKvwf,"}/*!sc*/
# .eDdhet{position:absolute;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;height:100%;}/*!sc*/
# data-styled.g185[id="Tiles__TileBackground-fk0fs3-0"]{content:"eDdhet,"}/*!sc*/
# .irebmk{background-color:rgb(232,233,234);position:relative;border-radius:8px;overflow:hidden;cursor:pointer;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;width:100%;height:100%;outline:none;}/*!sc*/
# @media (hover:hover){.irebmk{-webkit-mask-image:-webkit-radial-gradient(white,black);}.irebmk > .Tiles__TileBackground-fk0fs3-0{-webkit-transition:-webkit-transform 0.45s cubic-bezier(0.645,0.045,0.355,1);-webkit-transition:transform 0.45s cubic-bezier(0.645,0.045,0.355,1);transition:transform 0.45s cubic-bezier(0.645,0.045,0.355,1);}.irebmk:hover > .Tiles__TileBackground-fk0fs3-0{-webkit-transform:scale(1.1);-ms-transform:scale(1.1);transform:scale(1.1);}.irebmk:focus-visible{-webkit-mask-image:none;}}/*!sc*/
# .irebmk:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g186[id="Tiles__TileContainer-fk0fs3-1"]{content:"irebmk,"}/*!sc*/
# .ZXEpq{min-width:44px;min-height:44px;width:44px;height:44px;overflow:visible;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g237[id="IconButton-sc-1hr6tt4-0"]{content:"ZXEpq,"}/*!sc*/
# .bcrqWm{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;padding:2px 8px;border-radius:4px;background-color:rgb(232,233,234);cursor:default;}/*!sc*/
# .bcrqWm:focus{outline:none;box-shadow:0 0 1px 1px rgb(107,119,128);}/*!sc*/
# data-styled.g244[id="Tag__TagBase-sc-1rp6fz0-1"]{content:"bcrqWm,"}/*!sc*/
# .jVMCHF{margin-right:4px;text-transform:uppercase;background-color:rgb(255,255,255);color:rgb(5,34,134);font-size:12px;line-height:1.33;padding:2px 4px;}/*!sc*/
# .jVMCHF .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:15.96px;width:15.96px;}/*!sc*/
# data-styled.g245[id="PropertyTag-sc-5t90lx-0"]{content:"jVMCHF,"}/*!sc*/
# .cyMyhd{margin:4px 0;border-top:1px solid rgb(205,209,212);padding-top:8px;}/*!sc*/
# data-styled.g259[id="PropertyCard__PropertyCardExtendedContentContainer-m1ur0x-0"]{content:"cyMyhd,"}/*!sc*/
# .kehSAX{text-transform:uppercase;line-height:13px;padding-bottom:4px;}/*!sc*/
# data-styled.g260[id="PropertyCard__CapitalizedText-m1ur0x-1"]{content:"kehSAX,"}/*!sc*/
# .CEYnN{display:inline-block;width:100%;border-radius:8px;}/*!sc*/
# .CEYnN:hover{cursor:pointer;}/*!sc*/
# data-styled.g261[id="PropertyCard__InteractivePropertyCardContainer-m1ur0x-2"]{content:"CEYnN,"}/*!sc*/
# .dgzfOv{display:block;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# data-styled.g262[id="PropertyCard__StyledLink-m1ur0x-3"]{content:"dgzfOv,"}/*!sc*/
# .faCQjz{min-width:224px;width:224px;width:100%;height:100%;}/*!sc*/
# .faCQjz a,.faCQjz a:hover{color:inherit;}/*!sc*/
# data-styled.g263[id="PropertyCard__PropertyCardContainer-m1ur0x-4"]{content:"faCQjz,"}/*!sc*/
# .efHvis{position:relative;z-index:0;height:calc(100% - 104px);}/*!sc*/
# data-styled.g274[id="PropertyCardMedia__PropertyCardMediaContainer-qb9jxv-0"]{content:"efHvis,"}/*!sc*/
# .kNXJNq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:80%;height:19px;overflow:hidden;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;position:absolute;top:8px;left:8px;}/*!sc*/
# data-styled.g275[id="PropertyCardMedia__PropertyTagsContainer-qb9jxv-1"]{content:"kNXJNq,"}/*!sc*/
# .jJFkQV{position:absolute;top:0;right:0;z-index:1;}/*!sc*/
# data-styled.g278[id="PropertyCardMedia__SaveHomeButtonContainer-qb9jxv-4"]{content:"jJFkQV,"}/*!sc*/
# .hmgeux{min-height:160px;}/*!sc*/
# data-styled.g279[id="PropertyCardMedia__PhotoTileContainer-qb9jxv-5"]{content:"hmgeux,"}/*!sc*/
# .hPToJy{position:absolute;left:-10000px;-webkit-clip:rect(1px 1px 1px 1px);clip:rect(1px 1px 1px 1px);-webkit-clip:rect(1px,1px,1px,1px);clip:rect(1px,1px,1px,1px);padding:0;border:0;height:1px;width:1px;overflow:hidden;}/*!sc*/
# data-styled.g302[id="ScreenReaderContent-sc-1y1ua5d-0"]{content:"hPToJy,"}/*!sc*/
# .dGKnAF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;width:100%;}/*!sc*/
# data-styled.g322[id="Breadcrumb__ListContainer-sc-9uq83w-0"]{content:"dGKnAF,"}/*!sc*/
# .branch-banner-is-active{padding-top:64px;}/*!sc*/
# data-styled.g458[id="sc-global-KWXGC1"]{content:"sc-global-KWXGC1,"}/*!sc*/
# @font-face{font-family:"TruliaSans";src: url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Regular.woff2") format("woff2"), url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Regular.woff") format("woff");font-weight:400;font-style:normal;font-display:swap;}/*!sc*/
# @font-face{font-family:"TruliaSans";src: url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Bold.woff2") format("woff2"), url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Bold.woff") format("woff");font-weight:600;font-style:normal;font-display:swap;}/*!sc*/
# @font-face{font-family:"Trulia-Fallback";size-adjust:102%;ascent-override:90%;-webkit-descent-override:30%;descent-override:30%;src:local("Arial");}/*!sc*/
# html,body{margin:0;padding:0;font-family:'TruliaSans',Trulia-Fallback,sans-serif;color:rgb(59,65,68);background-color:rgb(255,255,255);font-size:16px;line-height:1.5;-webkit-letter-spacing:-.1px;-moz-letter-spacing:-.1px;-ms-letter-spacing:-.1px;letter-spacing:-.1px;}/*!sc*/
# html .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0,body .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# *{box-sizing:border-box;}/*!sc*/
# ::-moz-focus-inner{border:0;}/*!sc*/
# a{color:rgb(0,120,130);-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# a:hover{color:rgb(0,69,75);}/*!sc*/
# a:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# ul{margin:0;padding:0;list-style:none;}/*!sc*/
# h1,h2,h3,h4,h5,h6{margin-top:0;margin-bottom:8px;}/*!sc*/
# h1{font-size:28px;}/*!sc*/
# h2{font-size:24px;}/*!sc*/
# h3{font-size:20px;}/*!sc*/
# h4{font-size:16px;}/*!sc*/
# h5{font-size:14px;}/*!sc*/
# h6{font-size:12px;}/*!sc*/
# input,button,textarea{font-family:'TruliaSans',Trulia-Fallback,sans-serif;font-size:16px;line-height:1.5;}/*!sc*/
# input .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0,button .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0,textarea .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .modalActive{overflow:hidden !important;max-height:100%;}/*!sc*/
# .focus-visible,.focus-visible:focus{-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g459[id="sc-global-iTmeyC1"]{content:"sc-global-iTmeyC1,"}/*!sc*/
# .fciuBk{width:100%;height:64px;}/*!sc*/
# .fciuBk > *{z-index:100;position:fixed;border-bottom:none;}/*!sc*/
# @media (max-height:319px){.fciuBk > *{position:static;}}/*!sc*/
# data-styled.g465[id="SearchResultsHeader__HeaderContainer-j4zvtf-0"]{content:"fciuBk,"}/*!sc*/
# .fdsGMZ{font-size:16px;color:rgb(107,119,128);font-weight:normal;margin:0;padding-bottom:8px;}/*!sc*/
# data-styled.g474[id="SearchResultsHeadings__ResultCountText-sc-1cad3tj-1"]{content:"fdsGMZ,"}/*!sc*/
# ...
#               expires: 14,
#             });
#           }
#         }, 15000);
#
#       </script><script defer="" src="//micro.rubiconproject.com/prebid/dynamic/12222.js"></script><script defer="" src="//www.googletagservices.com/tag/js/gpt.js"></script><script>var pbjs = pbjs || {};pbjs.que = pbjs.que || [];window.googletag = window.googletag || {cmd: []};</script><meta charset="utf-8"/><title>San Diego, CA Homes For Sale &amp; San Diego, CA Real Estate | Trulia</title><meta content="1,519 Homes For Sale in San Diego, CA. Browse photos, see new properties, get open house info, and research neighborhoods on Trulia." name="description"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, viewport-fit=cover, minimal-ui" name="viewport"/><meta content="5953837487" property="fb:admins"/><meta content="183577541666001" property="fb:app_id"/><meta content="Trulia" property="application-name"/><meta content="https://www.trulia.com" property="msapplication-starturl"/><meta content="Trulia: Real Estate Search" property="msapplication-tooltip"/><meta content="/browserconfig.xml" property="msapplication-config"/><meta content="en_US" property="og:locale"/><meta content="Trulia Real Estate Search" property="og:site_name"/><meta content="website" property="og:type"/><meta content="@trulia" property="twitter:site"/><meta content="yes" property="mobile-web-app-capable"/><meta content="#ffffff" property="theme-color"/><meta content="yes" property="apple-mobile-web-app-capable"/><link href="https://assets.adobedtm.com" rel="preconnect"/><link href="https://maps.googleapis.com" rel="preconnect"/><link href="https://collector-PXYO6YjwLb.px-cloud.net" rel="preconnect"/><link href="https://assets.adobedtm.com" rel="dns-prefetch"/><link href="https://maps.googleapis.com" rel="dns-prefetch"/><link href="https://collector-PXYO6YjwLb.px-cloud.net" rel="dns-prefetch"/><link href="/manifest" rel="manifest"/><link href="//www.trulia.com/images/icons/app/app-icon-120.png" rel="apple-touch-icon-precomposed"/><link href="//www.trulia.com/images/icons/app/app-icon-144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="//www.trulia.com/images/icons/app/app-icon-152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="//www.trulia.com/images/icons/app/app-icon-180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/><link href="//www.trulia.com/images/icons/app/app-icon-196.png" rel="shortcut icon" sizes="196x196"/><link href="//www.trulia.com/images/icons/favicon-rebrand-128.png" rel="icon" sizes="120x120"/><link href="//www.trulia.com/images/icons/favicon-rebrand-196.png" rel="icon" sizes="196x196"/><link href="//www.trulia.com/images/icons/app/app-icon-228.png" rel="icon" sizes="228x228"/><link color="#00ADBB" href="//www.trulia.com/images/icons/mask-icon.svg" rel="mask-icon"/><link as="image" href="https://www.trulia.com/pictures/thumbs_3/zillowstatic/fp/1a2743b4e086b5f5ad7f795cddbe135c-full.jpg" imagesrcset="" rel="preload"/><link href="android-app://com.trulia.android/https/www.trulia.com/CA/San_Diego/" rel="alternate"/><link href="ios-app://288487321/https/www.trulia.com/CA/San_Diego/" rel="alternate"/><link href="https://www.trulia.com/CA/San_Diego/" rel="canonical"/><link href="https://www.trulia.com/CA/San_Diego/2_p/" rel="next"/><meta content="INDEX, FOLLOW" name="robots"/><meta content="https://www.trulia.com/CA/San_Diego/" property="og:url"/><meta content="1,519 Homes For Sale in San Diego, CA. Browse photos, see new properties, get open house info, and research neighborhoods on Trulia." property="og:description"/><meta content="San Diego, CA Homes For Sale &amp; San Diego, CA Real Estate | Trulia" property="og:title"/><meta content="https://www.trulia.com/images/logos/standardized/v4/logo-with-icon-200x200.png" property="og:image"/><meta content="200" property="og:image:width"/><meta content="200" property="og:image:height"/><meta content="45" name="next-head-count"/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="https://www.trulia.com/assets/_nex ...
#       if (
#         window.performance &&
#         window.performance.mark &&
#         window.performance.measure
#       ) {
#         var cards = document.querySelectorAll('[data-hero-element-id="srp-home-card"]');
#         var loadedImages = [];
#
#         for (var i = 0; i < cards.length; i++) {
#           var image = cards[i].querySelector('img');
#           if (image.complete) {
#             loadedImages.push(Promise.resolve(image));
#           } else {
#             loadedImages.push(
#               new Promise(function (accept) {
#                 image.addEventListener('load', function () {
#                   accept(this);
#                 });
#               })
#             );
#           }
#         }
#
#         Promise.all(loadedImages).then(function() {
#           window.performance.mark('hero_image_load_end');
#           window.performance.measure('hero_image_load');
#
#           performance.clearMarks('hero_element_displayed');
#           performance.mark('hero_element_displayed');
#         });
#       }
#     </script></div><script data-testid="srp-list-open-house-markup" type="application/ld+json">{"@context":"http://schema.org","@type":"Event","startDate":"2021-09-11T17:00:00+00:00","endDate":"2021-09-11T19:00:00+00:00","name":"Open House: 10AM-12PM","url":"https://www.trulia.com/p/ca/san-diego/1753-49th-st-san-diego-ca-92102--2079678232","description":"1753 49th St Open House","location":{"@type":"Place","name":"1753 49th St, San Diego, CA 92102","address":{"@type":"PostalAddress","addressLocality":"San Diego","addressRegion":"CA","postalCode":"92102","streetAddress":"1753 49th St"},"geo":{"@type":"GeoCoordinates","latitude":32.724117,"longitude":-117.089439}},"image":"https://www.trulia.com/pictures/thumbs_5/zillowstatic/fp/99294eb573c064a4e0633e4efaa3ca41-full.jpg","offers":{"price":659000,"priceCurrency":"USD","availability":"http://schema.org/InStock","url":"https://www.trulia.com/p/ca/san-diego/1753-49th-st-san-diego-ca-92102--2079678232","validFrom":"2021-09-11T17:00:00+00:00"}}</script><script data-testid="srp-list-open-house-markup" type="application/ld+json">{"@context":"http://schema.org","@type":"Event","startDate":"2021-09-12T19:00:00+00:00","endDate":"2021-09-12T21:00:00+00:00","name":"Open House: 12PM-2PM","url":"https://www.trulia.com/p/ca/san-diego/173-siena-st-san-diego-ca-92114--2079811202","description":"173 Siena St Open House","location":{"@type":"Place","name":"173 Siena St, San Diego, CA 92114","address":{"@type":"PostalAddress","addressLocality":"San Diego","addressRegion":"CA","postalCode":"92114","streetAddress":"173 Siena St"},"geo":{"@type":"GeoCoordinates","latitude":32.704803,"longitude":-117.03624}},"image":"https://www.trulia.com/pictures/thumbs_5/zillowstatic/fp/6d79d07e580a335b4453c82cec1765b2-full.jpg","offers":{"price":649999,"priceCurrency":"USD","availability":"http://schema.org/InStock","url":"https://www.trulia.com/p/ca/san-diego/173-siena-st-san-diego-ca-92114--2079811202","validFrom":"2021-09-12T19:00:00+00:00"}}</script><script data-testid="srp-list-open-house-markup" type="application/ld+json">{"@context":"http://schema.org","@type":"Event","startDate":"2021-09-12T20:00:00+00:00","endDate":"2021-09-12T23:00:00+00:00","name":"Open House: 1PM-4PM","url":"https://www.trulia.com/p/ca/san-diego/3266-willard-st-san-diego-ca-92122--2079898334","description":"3266 Willard St Open House","location":{"@type":"Place","name":"3266 Willard St, San Diego, CA 92122","address":{"@type":"PostalAddress","addressLocality":"San Diego","addressRegion":"CA","postalCode":"92122","streetAddress":"3266 Willard St"},"geo":{"@type":"GeoCoordinates","latitude":32.853249,"longitude":-117.215256}},"image":"https://www.trulia.com/pictures/thumbs_5/zillowstatic/fp/425f7f958779ca350a78ec2d4652611c-full.jpg","offers":{"price":1395000,"priceCurrency":"USD","availability":"http://schema.org/InStock","url":"https://www.trulia.com/p/ca/san-diego/3266-willard-st-san-diego-ca-92122--2079898334","validFrom":"2021-09-12T20:00:00+00:00"}}</script><script data-testid="srp-list-open-house-markup" type="application/ld+json">{"@context":"http://schema.org","@type":"Event","startDate":"2021-09-12T20:00:00+00:00","endDate":"2021-09-12T23:00:00+00:00","name":"Open House: 1PM-4PM","url":"https://www.trulia.com/p/ca/san-diego/7155-tuxedo-rd-san-diego-ca-92119--2079878985","description":"7155 Tuxedo Rd Open House","location":{"@type":"Place","name":"7155 Tuxedo Rd, San Diego, CA 92119","address":{"@type":"PostalAddress","addressLocality":"San Diego","addressRegion":"CA","postalCode":"92119","streetAddress":"7155 Tuxedo Rd"},"geo":{"@type":"GeoCoordinates","latitude":32.81007,"longitude":-117.040581}},"image":"https://www.trulia.com/pictures/thumbs_5/zillowstatic/fp/0acb23e4dc332b6d21b47c6bdb99fd16-full.jpg","offers":{"price":979000,"priceCurrency":"USD","availability":"http://schema.org/InStock","url":"https://www.trulia.com/p/ca/san-diego/7155-tuxedo-rd-san-diego-ca-92119--2079878985","validFrom":"2021-09-12T20:00:00+00:00"}}</scrip ...
# BEFORE MAKING ANY OTHER DECISION, YOU SHOULD PERSONALLY INVESTIGATE THE FACTS (e.g. square footage and lot size) with the assistance of an appropriate professional. You may use this information only to identify properties you may be interested in investigating further. All uses except for personal, noncommercial use in accordance with the foregoing purpose are prohibited. Redistribution or copying of this information, any photographs or video tours is strictly
# prohibited. This information is derived from the Internet Data Exchange (IDX) service provided by San Diego MLS. Displayed property listings may be held by a brokerage firm other than the broker and/or agent responsible for this display. The information and any photographs and video tours and the compilation from which they are derived is protected by copyright. Compilation © 2021 San Diego MLS.</div></div></div><div class="SearchResultsProviderAttribution__AttributionContainer-sc-29f6u2-0 mzPQo" data-testid="srp-provider-attribution"><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 oVGDp" style="display:flex"><div class="Padding-sc-1tki7vp-0 dtoUNs" style="line-height:0;display:flex;justify-content:center;align-items:center"><img class="Image__ImageContainer-sc-1motiir-0 emFnwq" decoding="async" loading="lazy" src="https://photos.zillowstatic.com/fp/f232d814f101beef502c9fe4fc0167fb-trulia_inf_40.jpeg" style="max-height:24px;height:unset"/></div></div></div><div class="SearchResultsProviderAttribution__AttributionContainer-sc-29f6u2-0 mzPQo" data-testid="srp-provider-attribution"></div></div><div class="SearchResultsContentLayout__FooterContainer-sc-4wj1i6-4 iMOUvQ"><footer class="Footer__FooterContainer-h25adx-0 ivICeq"><div class="NavigationSecondary__Container-sc-59f6ac-0 dyUsOb"><div class="NavigationSecondary__Inner-sc-59f6ac-1 iagBDf"><div class="LinkColumn__Column-sc-18qnqbg-4 gfYCGU"><ul class="List__ListContainer-sc-8uj508-0 ljHPkT"><li><h4 class="LinkColumn__LinkColumnHeading-sc-18qnqbg-2 eiMzua" id="nearby_real_estate" style="margin:0 0 8px 0"><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 gA-DbwZ">Nearby Real Estate</div></h4></li><li class="LinkColumn__ListItem-sc-18qnqbg-0 fLjkrG"><a class="LinkColumn__Link-sc-18qnqbg-1 chUtxH" href="/condos-for-sale-near-me/"><span class="Text__TextBase-sc-1cait9d-0 dujbAG">Condos for Sale Near Me</span></a></li><li class="LinkColumn__ListItem-sc-18qnqbg-0 fLjkrG"><a class="LinkColumn__Link-sc-18qnqbg-1 chUtxH" href="/houses-for-sale-near-me/"><span class="Text__TextBase-sc-1cait9d-0 dujbAG">Houses for Sale Near Me</span></a></li><li class="LinkColumn__ListItem-sc-18qnqbg-0 fLjkrG"><a class="LinkColumn__Link-sc-18qnqbg-1 chUtxH" href="/houses-for-sale-near-me-by-owner/"><span class="Text__TextBase-sc-1cait9d-0 dujbAG">Houses for Sale Near Me by Owner</span></a></li><li class="LinkColumn__ListItem-sc-18qnqbg-0 fLjkrG"><a class="LinkColumn__Link-sc-18qnqbg-1 chUtxH" href="/open-houses-near-me/"><span class="Text__TextBase-sc-1cait9d-0 dujbAG">Open Houses Near Me</span></a></li><li class="LinkColumn__ListItem-sc-18qnqbg-0 iXDUHN"><div aria-describedby="nearby_real_estate" aria-expanded="false" class="Box__BoxElement-sc-1f5rw0h-0 bsjsJO BoxButton-sc-12vrxun-0 erxzVp LinkColumn__ToggleMenuButton-sc-18qnqbg-3 fGQGPu" role="button" tabindex="0"><span class="Text__TextBase-sc-1cait9d-0 kRmhGt Anchor__StyledText-sc-5lya7g-0 gSLuwD" color="highlight"><div class="MediaBlock__MediaContainer-skmvlj-0 eIkmHi"><div class="MediaBlock__MediaContent-skmvlj-1 gnreBg"><span class="Text__TextBase-sc-1cait9d-0 dujbAG">More</span></div><div class="getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 ijNWVp"><svg aria-hidden="true" aria-label="" class="svg" role="img" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M15.961 18.183l7.056-7.147 1.893 1.868-8.951 9.068-8.927-9.069 1.896-1.866z" fill="#869099"></path></svg></div></div></span></div></li><li class="LinkColumn__ListItem-sc-18qnqbg-0 etPKim"><a class="LinkColumn__Link-sc-18qnqbg-1 chUtxH" href="/land-for-sale-near-me/">Land for Sale Near Me</a></li><li class="LinkColumn__ListItem-sc-18qnqbg-0 etPKim"><a class="LinkColumn__Link-sc-18qnqbg-1 chUtxH" href="/townhomes-for-sale-near-me/">Townhomes for Sale Near Me</a></li><li class="LinkColumn__ListItem-sc-18qnqbg-0 etPKim"><a class="LinkColumn__Link-sc-18qnqbg-1 chUtxH" href="/CA/La_Jolla/">La Jolla Real Estate</a></li><li cl ...
#           function initTracking(pageviewPayload) {
#     let count = 0;
#     const MAX_COUNT = 100;
#     window.s = window.s || {};
#     window.trulia = window.trulia || {};
#     window.trulia.dataLayer = window.trulia.dataLayer || {};
#     window.trulia.dataLayer.referrer = document.referrer;
#
#     function listenersDefined() {
#       const listeners = window.trulia.dataLayer.listeners;
#       return typeof listeners !== 'undefined' && listeners.length !== 0;
#     }
#
#     const queue = [];
#
#     const track = function (event, data, isInitialPageView) {
#       if (processQueue()) {
#         handleEvent(event, data, isInitialPageView);
#       } else {
#         queue.push({
#           event: event,
#           data: data,
#           isInitialPageView: isInitialPageView
#         });
#       }
#     };
#
#     const handleEvent = function (event, data, isInitialPageView) {
#       if (isInitialPageView) {
#         window.s.referrer = window.trulia.dataLayer.referrer;
#       }
#
#       trulia.dataLayer.listeners.forEach(function (listener) {
#         listener(event, data);
#       });
#     };
#
#     const processQueue = function () {
#       if (listenersDefined()) {
#         if (queue.length) {
#           let queuedData;
#
#           while (queuedData = queue.shift()) {
#             handleEvent(queuedData.event, queuedData.data, queuedData.isInitialPageView);
#           }
#         }
#
#         return true;
#       }
#
#       if (count <= MAX_COUNT) {
#         setTimeout(processQueue, 300);
#         count += 1;
#       }
#
#       return false;
#     };
#
#     if (pageviewPayload) {
#       track('trackState', pageviewPayload, true);
#     }
#
#     window.trulia.dataLayer.track = track;
#   }
#           initTracking(null);
#         </script><script>
#             (function() {
#                 window._pxAppId = 'PXYO6YjwLb';
#                 // Custom parameters
#                 // window._pxParam1 = "<param1>";
#                 var p = document.getElementsByTagName('script')[0],
#                     s = document.createElement('script');
#                 s.async = 1;
#                 s.src = '//client.px-cloud.net/PXYO6YjwLb/main.min.js';
#                 p.parentNode.insertBefore(s, p);
#             }());
#             </script><noscript><div height="1" style="position:fixed;top:0;left:0;display:none" width="1"><img alt="px pixel" src="//collector-PXYO6YjwLb.px-cloud.net/api/v1/collector/noScript.gif?appId=PXYO6YjwLb"/></div></noscript></body></html>

# %% [markdown]
# ## 4) Results

# %%
result_container = soup.find_all('li', {'class':'SearchResultsList__WideCell-b7y9ki-2'})

# %%
len(result_container)
# Out:
# 42

# %% [markdown]
# ## 5) Update Results

# %% [markdown]
# **We need the elements which have the attribute 'data-testid':**

# %%
results_update = []

for r in result_container:
    if r.has_attr('data-testid'):
        results_update.append(r)

# %%
len(results_update)
# Out:
# 40

# %% [markdown]
# ## 6) Concatenate 2 Url Parts to get absolute url

# %% [markdown]
# #### a) Url part I:

# %%
url_1 = 'https://www.trulia.com'

# %% [markdown]
# #### b) Creating a list for Url part II:

# %%
url_2 = []

for i in results_update:
    for j in i.find_all('div', {'data-testid':'property-card-details'}):
        url_2.append(j.find('a').get('href'))

# %%
url_2
# Out:
# ['/p/ca/san-diego/1907-robinson-ave-108-san-diego-ca-92104--2079701553',
#  '/p/ca/san-diego/5250-lenox-dr-san-diego-ca-92114--2079814944',
#  '/p/ca/san-diego/7720-tyrolean-rd-san-diego-ca-92126--2079935792',
#  '/p/ca/san-diego/6124-artisan-way-san-diego-ca-92130--2365905698',
#  '/p/ca/san-diego/12614-darkwood-rd-san-diego-ca-92129--2079977957',
#  '/p/ca/san-diego/3078-broadway-107-san-diego-ca-92102--2079683296',
#  '/p/ca/san-diego/12048-rue-des-amis-san-diego-ca-92131--2080015943',
#  '/p/ca/san-diego/2287-loring-st-1-san-diego-ca-92109--2079762188',
#  '/p/ca/san-diego/4671-hamilton-st-4-san-diego-ca-92116--2079847521',
#  '/p/ca/san-diego/1951-47th-st-146-san-diego-ca-92102--2079678847',
#  '/p/ca/san-diego/5170-clairemont-mesa-blvd-51-18-san-diego-ca-92117--2504280231',
#  '/p/ca/san-diego/10676-rancho-carmel-dr-san-diego-ca-92128--2079957515',
#  '/p/ca/san-diego/4864-49th-st-san-diego-ca-92115--1020988340',
#  '/p/ca/san-diego/303-s-46th-st-san-diego-ca-92113--2146021556',
#  '/p/ca/san-diego/4545-collwood-blvd-20-san-diego-ca-92115--2079829871',
#  '/p/ca/san-diego/3228-44th-st-5-san-diego-ca-92105--2079720443',
#  '/p/ca/san-diego/3007-central-ave-san-diego-ca-92105--2079719490',
#  '/p/ca/san-diego/978-granger-st-san-diego-ca-92154--2080046502',
#  '/p/ca/san-diego/7620-stalmer-st-106-san-diego-ca-92111--2079797733',
#  '/p/ca/san-diego/2737-lungos-ct-san-diego-ca-92154--2080036785',
#  '/p/ca/san-diego/2930-naugatuck-ave-san-diego-ca-92117--2079851011',
#  '/p/ca/san-diego/4845-castle-ave-san-diego-ca-92105--2079729129',
#  '/p/ca/san-diego/3872-creststone-pl-san-diego-ca-92130--2080000004',
#  '/p/ca/san-diego/236-payne-st-san-diego-ca-92113--2079801019',
#  '/p/ca/san-diego/8190-califa-ct-san-diego-ca-92119--1020080341',
#  '/p/ca/san-diego/12535-alcacer-del-sol-san-diego-ca-92128--2079965102',
#  '/p/ca/san-diego/3135-manos-dr-san-diego-ca-92139--2080023097',
#  '/p/ca/san-diego/328-w-lewis-st-san-diego-ca-92103--2116269866',
#  '/p/ca/san-diego/821-reef-dr-san-diego-ca-92154--1043055098',
#  '/p/ca/san-diego/3573-chasewood-dr-san-diego-ca-92111--2079788702',
#  '/p/ca/san-diego/1656-yost-dr-san-diego-ca-92109--2079759068',
#  '/p/ca/san-diego/2615-nansen-ave-san-diego-ca-92122--2079897657',
#  '/p/ca/san-diego/11445-spica-dr-san-diego-ca-92126--2079933128',
#  '/p/ca/san-diego/4120-vivian-st-san-diego-ca-92115--2079826698',
#  '/p/ca/san-diego/880-60th-st-san-diego-ca-92114--1065253361',
#  '/p/ca/san-diego/5290-timber-branch-way-san-diego-ca-92130--2080004613',
#  '/p/ca/san-diego/5407-baja-dr-san-diego-ca-92115--2079834673',
#  '/p/ca/san-diego/4536-arizona-st-4-san-diego-ca-92116--2079845076',
#  '/p/ca/san-diego/8886-la-cartera-st-san-diego-ca-92129--2079986829',
#  '/p/ca/la-jolla/5850-camino-de-la-costa-la-jolla-ca-92037--2079478670']

# %%
len(url_2)
# Out:
# 40

# %% [markdown]
# #### c) Joining Url 1 and Url 2:

# %%
import urllib.parse

url_joined = []

for i in url_2:
    url_joined.append(urllib.parse.urljoin(url_1, i))

# %%
url_joined
# Out:
# ['https://www.trulia.com/p/ca/san-diego/1907-robinson-ave-108-san-diego-ca-92104--2079701553',
#  'https://www.trulia.com/p/ca/san-diego/5250-lenox-dr-san-diego-ca-92114--2079814944',
#  'https://www.trulia.com/p/ca/san-diego/7720-tyrolean-rd-san-diego-ca-92126--2079935792',
#  'https://www.trulia.com/p/ca/san-diego/6124-artisan-way-san-diego-ca-92130--2365905698',
#  'https://www.trulia.com/p/ca/san-diego/12614-darkwood-rd-san-diego-ca-92129--2079977957',
#  'https://www.trulia.com/p/ca/san-diego/3078-broadway-107-san-diego-ca-92102--2079683296',
#  'https://www.trulia.com/p/ca/san-diego/12048-rue-des-amis-san-diego-ca-92131--2080015943',
#  'https://www.trulia.com/p/ca/san-diego/2287-loring-st-1-san-diego-ca-92109--2079762188',
#  'https://www.trulia.com/p/ca/san-diego/4671-hamilton-st-4-san-diego-ca-92116--2079847521',
#  'https://www.trulia.com/p/ca/san-diego/1951-47th-st-146-san-diego-ca-92102--2079678847',
#  'https://www.trulia.com/p/ca/san-diego/5170-clairemont-mesa-blvd-51-18-san-diego-ca-92117--2504280231',
#  'https://www.trulia.com/p/ca/san-diego/10676-rancho-carmel-dr-san-diego-ca-92128--2079957515',
#  'https://www.trulia.com/p/ca/san-diego/4864-49th-st-san-diego-ca-92115--1020988340',
#  'https://www.trulia.com/p/ca/san-diego/303-s-46th-st-san-diego-ca-92113--2146021556',
#  'https://www.trulia.com/p/ca/san-diego/4545-collwood-blvd-20-san-diego-ca-92115--2079829871',
#  'https://www.trulia.com/p/ca/san-diego/3228-44th-st-5-san-diego-ca-92105--2079720443',
#  'https://www.trulia.com/p/ca/san-diego/3007-central-ave-san-diego-ca-92105--2079719490',
#  'https://www.trulia.com/p/ca/san-diego/978-granger-st-san-diego-ca-92154--2080046502',
#  'https://www.trulia.com/p/ca/san-diego/7620-stalmer-st-106-san-diego-ca-92111--2079797733',
#  'https://www.trulia.com/p/ca/san-diego/2737-lungos-ct-san-diego-ca-92154--2080036785',
#  'https://www.trulia.com/p/ca/san-diego/2930-naugatuck-ave-san-diego-ca-92117--2079851011',
#  'https://www.trulia.com/p/ca/san-diego/4845-castle-ave-san-diego-ca-92105--2079729129',
#  'https://www.trulia.com/p/ca/san-diego/3872-creststone-pl-san-diego-ca-92130--2080000004',
#  'https://www.trulia.com/p/ca/san-diego/236-payne-st-san-diego-ca-92113--2079801019',
#  'https://www.trulia.com/p/ca/san-diego/8190-califa-ct-san-diego-ca-92119--1020080341',
#  'https://www.trulia.com/p/ca/san-diego/12535-alcacer-del-sol-san-diego-ca-92128--2079965102',
#  'https://www.trulia.com/p/ca/san-diego/3135-manos-dr-san-diego-ca-92139--2080023097',
#  'https://www.trulia.com/p/ca/san-diego/328-w-lewis-st-san-diego-ca-92103--2116269866',
#  'https://www.trulia.com/p/ca/san-diego/821-reef-dr-san-diego-ca-92154--1043055098',
#  'https://www.trulia.com/p/ca/san-diego/3573-chasewood-dr-san-diego-ca-92111--2079788702',
#  'https://www.trulia.com/p/ca/san-diego/1656-yost-dr-san-diego-ca-92109--2079759068',
#  'https://www.trulia.com/p/ca/san-diego/2615-nansen-ave-san-diego-ca-92122--2079897657',
#  'https://www.trulia.com/p/ca/san-diego/11445-spica-dr-san-diego-ca-92126--2079933128',
#  'https://www.trulia.com/p/ca/san-diego/4120-vivian-st-san-diego-ca-92115--2079826698',
#  'https://www.trulia.com/p/ca/san-diego/880-60th-st-san-diego-ca-92114--1065253361',
#  'https://www.trulia.com/p/ca/san-diego/5290-timber-branch-way-san-diego-ca-92130--2080004613',
#  'https://www.trulia.com/p/ca/san-diego/5407-baja-dr-san-diego-ca-92115--2079834673',
#  'https://www.trulia.com/p/ca/san-diego/4536-arizona-st-4-san-diego-ca-92116--2079845076',
#  'https://www.trulia.com/p/ca/san-diego/8886-la-cartera-st-san-diego-ca-92129--2079986829',
#  'https://www.trulia.com/p/ca/la-jolla/5850-camino-de-la-costa-la-jolla-ca-92037--2079478670']

# %%
len(url_joined)
# Out:
# 40

# %% [markdown]
# ## 7) Get the data from the first link

# %% [markdown]
# #### a) Store the first link:

# %%
first_link = url_joined[0]

# %% [markdown]
# #### b) Get request and soup object:

# %%
response = requests.get(first_link)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><script>
#             window.__uspapi = function(command, version, callback) {
#               try {
#                 if (command === 'getUSPData') {
#                   var cookies = document.cookie.split(';');
#                   for (var i = 0; i < cookies.length; i++) {
#                     var cookie = cookies[i];
#                     var separatorIndex = cookie.indexOf('=');
#                     separatorIndex = separatorIndex < 0 ? cookie.length : separatorIndex;
#                     var cookie_name = decodeURIComponent(cookie.slice(0, separatorIndex).replace(/^\s+/, ''));
#                     if (cookie_name === 'usprivacy') {
#                       var uspString = decodeURIComponent(cookie.slice(separatorIndex + 1));
#                       callback({ version: version, uspString: uspString }, true);
#                       return;
#                     }
#                   }
#                 }
#               } catch (ex) {
#                 console.error(ex);
#               }
#               callback(null, false);
#             }
#
#             window.addEventListener('message', function(event) {
#               if (event && event.data && event.data.__uspapiCall
#                 && event.source && event.source.postMessage
#               ) {
#                 window.__uspapi(
#                   event.data.__uspapiCall.command,
#                   event.data.__uspapiCall.version,
#                   function(data, success) {
#                     event.source.postMessage({
#                       __uspapiReturn: {
#                         returnValue: data,
#                         success: success,
#                         callId: event.data.__uspapiCall.callId
#                       }
#                     });
#                   }
#                 );
#               }
#             }, false);
#           </script><script>
#           window.trulia = window.trulia || {};
#           trulia.analytics = trulia.analytics || {};
#           trulia.analytics.automaticTrackState = false;
#         </script><style data-styled="" data-styled-version="5.1.1">.eIkmHi{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .hdCHah{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g1[id="MediaBlock__MediaContainer-skmvlj-0"]{content:"eIkmHi,hdCHah,"}/*!sc*/
# .edhurL{margin:0 8px;overflow:hidden;}/*!sc*/
# .edhurL:last-child{margin-right:0;}/*!sc*/
# .edhurL:first-child{margin-left:0;}/*!sc*/
# .gnreBg{margin:0 4px;}/*!sc*/
# .gnreBg:last-child{margin-right:0;}/*!sc*/
# .gnreBg:first-child{margin-left:0;}/*!sc*/
# .BVZzV{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;width:100%;margin:0 8px;}/*!sc*/
# .BVZzV:last-child{margin-right:0;}/*!sc*/
# .BVZzV:first-child{margin-left:0;}/*!sc*/
# .dwmuOU{margin:0 8px;}/*!sc*/
# .dwmuOU:last-child{margin-right:0;}/*!sc*/
# .dwmuOU:first-child{margin-left:0;}/*!sc*/
# .jjMYLq{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;width:100%;margin:0;overflow:hidden;}/*!sc*/
# .jjMYLq:last-child{margin-right:0;}/*!sc*/
# .jjMYLq:first-child{margin-left:0;}/*!sc*/
# .jNJnVO{margin:0 2px;}/*!sc*/
# .jNJnVO:last-child{margin-right:0;}/*!sc*/
# .jNJnVO:first-child{margin-left:0;}/*!sc*/
# .qjlKt{margin:0 2px;overflow:hidden;}/*!sc*/
# .qjlKt:last-child{margin-right:0;}/*!sc*/
# .qjlKt:first-child{margin-left:0;}/*!sc*/
# .jtQacT{margin:0 4px;overflow:hidden;}/*!sc*/
# .jtQacT:last-child{margin-right:0;}/*!sc*/
# .jtQacT:first-child{margin-left:0;}/*!sc*/
# .bBOQmD{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;width:100%;margin:0 8px;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# .bBOQmD:last-child{margin-right:0;}/*!sc*/
# .bBOQmD:first-child{margin-left:0;}/*!sc*/
# data-styled.g2[id="MediaBlock__MediaContent-skmvlj-1"]{content:"edhurL,gnreBg,BVZzV,dwmuOU,jjMYLq,jNJnVO,qjlKt,jtQacT,bBOQmD,"}/*!sc*/
# .hIjpxF{width:32px !important;height:32px !important;display:inline-block;font-size:0;}/*!sc*/
# .hIjpxF .svg{width:32px;}/*!sc*/
# .hIjpxF .svg{height:32px;}/*!sc*/
# .hIjpxF path{fill:rgb(0,120,130);}/*!sc*/
# .cAsKxs{width:16px !important;height:16px !important;display:inline-block;font-size:0;}/*!sc*/
# .cAsKxs .svg{width:16px;}/*!sc*/
# .cAsKxs .svg{height:16px;}/*!sc*/
# .cAsKxs path{fill:rgb(107,119,128);}/*!sc*/
# .hnYFju{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .hnYFju .svg{width:24px;}/*!sc*/
# .hnYFju .svg{height:24px;}/*!sc*/
# .hnYFju path{fill:rgb(255,255,255);}/*!sc*/
# .jlplot{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .jlplot .svg{width:24px;}/*!sc*/
# .jlplot .svg{height:24px;}/*!sc*/
# .jlplot path{fill:rgb(0,120,130);}/*!sc*/
# .ijNWVp{width:20px !important;height:20px !important;display:inline-block;font-size:0;}/*!sc*/
# .ijNWVp .svg{width:20px;}/*!sc*/
# .ijNWVp .svg{height:20px;}/*!sc*/
# .ijNWVp path{fill:rgb(0,120,130);}/*!sc*/
# .bDMRDK{width:16px !important;height:16px !important;display:inline-block;font-size:0;}/*!sc*/
# .bDMRDK .svg{width:16px;}/*!sc*/
# .bDMRDK .svg{height:16px;}/*!sc*/
# .bDMRDK path{fill:rgb(255,255,255);}/*!sc*/
# .bXOPul{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .bXOPul .svg{width:24px;}/*!sc*/
# .bXOPul .svg{height:24px;}/*!sc*/
# .bXOPul path{fill:rgb(59,65,68);}/*!sc*/
# .kchZQt{width:18px !important;height:18px !important;display:inline-block;font-size:0;}/*!sc*/
# .kchZQt .svg{width:18px;}/*!sc*/
# .kchZQt .svg{height:18px;}/*!sc*/
# .kchZQt path{fill:rgb(59,65,68);}/*!sc*/
# .duTZbN{width:16px !important;height:16px !important;display:inline-block;font-size:0;}/*!sc*/
# .duTZbN .svg{width:16px;}/*!sc*/
# .duTZbN .svg{height:16px;}/*!sc*/
# .duTZbN path{fill:rgb(59,65,68);}/*!sc*/
# .csIvyu{width:20px !important;height:20px !important;display:inline-block;font-size:0;}/*!sc*/
# .csIvyu .svg{width:20px;}/*!sc*/
# .csIvyu .svg{height:20px;}/*!sc*/
# .csIvyu path{fill:rgb(0,133,69);}/*!sc*/
# .dEvZww{width:20px !important;height:20px !important;display:inline-block;font-size:0;}/*!sc*/
# .dEvZww .svg{width:20px;}/*!sc*/
# .dEvZww .svg{height:20px;}/*!sc*/
# .dEvZww path{fill:rgb(217,60,35);}/*!sc*/
# .bosPhI{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .bosPhI .svg{width:24px;}/*!sc*/
# .bosPhI .svg{height:24px;}/*!sc*/
# .bosPhI path{fill:rgb(107,119,128);}/*!sc*/
# .iemARF{width:16px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .iemARF .svg{width:16px;}/*!sc*/
# .iemARF .svg{height:24px;}/*!sc*/
# .iemARF path{fill:rgb(0,120,130);}/*!sc*/
# .ckNPAJ{width:16px !important;height:16px !important;display:inline-block;font-size:0;}/*!sc*/
# .ckNPAJ .svg{width:16px;}/*!sc*/
# .ckNPAJ .svg{height:16px;}/*!sc*/
# .ckNPAJ path{fill:rgb(0,120,130);}/*!sc*/
# data-styled.g3[id="getUiSvgContainer__SvgContainer-sc-1cdn1ln-0"]{content:"hIjpxF,cAsKxs,hnYFju,jlplot,ijNWVp,bDMRDK,bXOPul,kchZQt,duTZbN,csIvyu,dEvZww,bosPhI,iemARF,ckNPAJ,"}/*!sc*/
# .dROcJl{display:none;}/*!sc*/
# .bsjsJO{display:block;}/*!sc*/
# .jqAYVe{display:block;border-style:solid !important;border-color:rgb(205,209,212);border-width:0 0 1px 0;}/*!sc*/
# .fqOxUT{display:none;}/*!sc*/
# @media (min-width:376px){.fqOxUT{display:none;}}/*!sc*/
# @media (min-width:570px){.fqOxUT{display:block;}}/*!sc*/
# @media (min-width:768px){.fqOxUT{display:block;}}/*!sc*/
# .idpokT{display:block;}/*!sc*/
# @media (min-width:376px){.idpokT{display:block;}}/*!sc*/
# @media (min-width:570px){.idpokT{display:none;}}/*!sc*/
# @media (min-width:768px){.idpokT{display:none;}}/*!sc*/
# .jlkWrz{display:none;}/*!sc*/
# @media (min-width:376px){.jlkWrz{display:none;}}/*!sc*/
# @media (min-width:570px){.jlkWrz{display:none;}}/*!sc*/
# @media (min-width:768px){.jlkWrz{display:block;}}/*!sc*/
# @media (min-width:993px){.jlkWrz{display:block;}}/*!sc*/
# .gGYVWf{display:none;}/*!sc*/
# @media (min-width:376px){.gGYVWf{display:block;}}/*!sc*/
# @media (min-width:570px){.gGYVWf{display:none;}}/*!sc*/
# @media (min-width:768px){.gGYVWf{display:block;}}/*!sc*/
# .hJHwzI{display:none;}/*!sc*/
# @media (min-width:376px){.hJHwzI{display:none;}}/*!sc*/
# @media (min-width:570px){.hJHwzI{display:block;}}/*!sc*/
# @media (min-width:768px){.hJHwzI{display:none;}}/*!sc*/
# .hCLjPy{width:0%;display:none;}/*!sc*/
# @media (min-width:376px){.hCLjPy{width:0%;}}/*!sc*/
# @media (min-width:570px){.hCLjPy{width:0%;}}/*!sc*/
# @media (min-width:768px){.hCLjPy{width:0%;}}/*!sc*/
# @media (min-width:993px){.hCLjPy{width:33.4%;}}/*!sc*/
# @media (min-width:376px){.hCLjPy{display:none;}}/*!sc*/
# @media (min-width:570px){.hCLjPy{display:none;}}/*!sc*/
# @media (min-width:768px){.hCLjPy{display:none;}}/*!sc*/
# @media (min-width:993px){.hCLjPy{display:block;}}/*!sc*/
# .gfzctK{width:100%;overflow:hidden;display:block;}/*!sc*/
# data-styled.g4[id="Box__BoxElement-sc-1f5rw0h-0"]{content:"dROcJl,bsjsJO,jqAYVe,fqOxUT,idpokT,jlkWrz,gGYVWf,hJHwzI,hCLjPy,gfzctK,"}/*!sc*/
# .fAXlbl{cursor:pointer;display:inline;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# .fAXlbl[role='button']:active{outline:none;box-shadow:0 0 0 1px rgb(107,119,128);}/*!sc*/
# .fAXlbl:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .limZBd{cursor:pointer;display:block;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# .limZBd[role='button']:active{outline:none;box-shadow:0 0 0 1px rgb(107,119,128);}/*!sc*/
# .limZBd:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .erxzVp{cursor:pointer;display:inline-block;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# .erxzVp[role='button']:active{outline:none;box-shadow:0 0 0 1px rgb(107,119,128);}/*!sc*/
# .erxzVp:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g5[id="BoxButton-sc-12vrxun-0"]{content:"fAXlbl,limZBd,erxzVp,"}/*!sc*/
# .gCjLgA{font-weight:bold;}/*!sc*/
# .cDHwql{font-weight:bold;font-size:14px;line-height:1.43;}/*!sc*/
# .cDHwql .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;width:20.02px;}/*!sc*/
# .bxzLaH{font-size:14px;line-height:1.43;}/*!sc*/
# .bxzLaH .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;width:20.02px;}/*!sc*/
# .djfnOw{color:rgb(107,119,128);}/*!sc*/
# .gkLagX{color:rgb(255,255,255);font-size:14px;line-height:1.43;}/*!sc*/
# .gkLagX .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;width:20.02px;}/*!sc*/
# .ifMipu{font-weight:bold;font-size:20px;line-height:1.2;}/*!sc*/
# @media (min-width:376px){.ifMipu{font-size:28px;}}/*!sc*/
# @media (min-width:570px){.ifMipu{font-size:20px;}}/*!sc*/
# @media (min-width:768px){.ifMipu{font-size:28px;}}/*!sc*/
# @media (min-width:376px){.ifMipu{line-height:1.14;}}/*!sc*/
# @media (min-width:570px){.ifMipu{line-height:1.2;}}/*!sc*/
# @media (min-width:768px){.ifMipu{line-height:1.14;}}/*!sc*/
# .ifMipu .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# @media (min-width:376px){.ifMipu .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:31.919999999999998px;}}/*!sc*/
# @media (min-width:570px){.ifMipu .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;}}/*!sc*/
# @media (min-width:768px){.ifMipu .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:31.919999999999998px;}}/*!sc*/
# @media (min-width:376px){.ifMipu .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:31.919999999999998px;}}/*!sc*/
# @media (min-width:570px){.ifMipu .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:24px;}}/*!sc*/
# @media (min-width:768px){.ifMipu .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:31.919999999999998px;}}/*!sc*/
# .cZbUGb{font-size:16px;line-height:1.5;}/*!sc*/
# .cZbUGb .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .kRmhGt{color:rgb(0,120,130);}/*!sc*/
# .liwNyG{font-size:12px;line-height:1.33;}/*!sc*/
# .liwNyG .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:15.96px;width:15.96px;}/*!sc*/
# data-styled.g7[id="Text__TextBase-sc-1cait9d-0"]{content:"gCjLgA,cDHwql,bxzLaH,djfnOw,gkLagX,ifMipu,cZbUGb,kRmhGt,dujbAG,liwNyG,"}/*!sc*/
# .ijolhc{color:rgb(0,120,130);font-weight:bold;font-size:16px;line-height:1.5;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .ijolhc .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .npfRF{color:rgb(255,255,255);}/*!sc*/
# .nBoMt{font-weight:bold;font-size:20px;line-height:1.2;}/*!sc*/
# @media (min-width:376px){.nBoMt{font-size:28px;}}/*!sc*/
# @media (min-width:570px){.nBoMt{font-size:20px;}}/*!sc*/
# @media (min-width:768px){.nBoMt{font-size:28px;}}/*!sc*/
# @media (min-width:376px){.nBoMt{line-height:1.14;}}/*!sc*/
# @media (min-width:570px){.nBoMt{line-height:1.2;}}/*!sc*/
# @media (min-width:768px){.nBoMt{line-height:1.14;}}/*!sc*/
# .nBoMt .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# @media (min-width:376px){.nBoMt .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:31.919999999999998px;}}/*!sc*/
# @media (min-width:570px){.nBoMt .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;}}/*!sc*/
# @media (min-width:768px){.nBoMt .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:31.919999999999998px;}}/*!sc*/
# @media (min-width:376px){.nBoMt .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:31.919999999999998px;}}/*!sc*/
# @media (min-width:570px){.nBoMt .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:24px;}}/*!sc*/
# @media (min-width:768px){.nBoMt .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:31.919999999999998px;}}/*!sc*/
# .bjqKkI{font-size:16px;line-height:1.5;}/*!sc*/
# .bjqKkI .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .ilVROc{font-weight:bold;font-size:20px;line-height:1.2;}/*!sc*/
# .ilVROc .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .juzGEy{font-weight:bold;font-size:16px;line-height:1.5;}/*!sc*/
# .juzGEy .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .fkSzsq{color:rgb(0,120,130);}/*!sc*/
# .jihWDw{font-size:14px;line-height:1.43;}/*!sc*/
# .jihWDw .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;width:20.02px;}/*!sc*/
# .cTGlQX{font-weight:bold;}/*!sc*/
# .ensgkS{color:rgb(107,119,128);font-size:16px;line-height:1.5;}/*!sc*/
# .ensgkS .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .keMYfJ{font-weight:bold;font-size:20px;line-height:1.2;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .keMYfJ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .dZyoXR{font-size:16px;line-height:1.5;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .dZyoXR .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .ccZuZv{color:rgb(107,119,128);font-size:10px;line-height:1.6;}/*!sc*/
# .ccZuZv .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:16px;width:16px;}/*!sc*/
# .kgxmNH{color:rgb(107,119,128);}/*!sc*/
# .PopYU{white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .kRjOhW{font-weight:bold;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .faLGMa{color:rgb(59,65,68);}/*!sc*/
# .eZInmq{min-height:calc(2 * 24px);}/*!sc*/
# .cYYbIw{font-size:12px;line-height:1.33;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .cYYbIw .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:15.96px;width:15.96px;}/*!sc*/
# .hiOoPn{font-size:20px;line-height:1.2;max-height:calc(7 * 24px);overflow:hidden;position:relative;min-height:calc(7 * 24px);}/*!sc*/
# .hiOoPn .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .hiOoPn:after{content:'';position:absolute;bottom:0;left:0;right:0;height:40.8px;background-image:linear-gradient( rgba(0,86,93,0) 0%, rgba(0,86,93,1) 100% );}/*!sc*/
# .eAGsOb{font-size:20px;line-height:1.2;max-height:calc(7 * 24px);overflow:hidden;position:relative;min-height:calc(7 * 24px);}/*!sc*/
# .eAGsOb .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .eAGsOb:after{content:'';position:absolute;bottom:0;left:0;right:0;height:40.8px;background-image:linear-gradient( rgba(20,66,37,0) 0%, rgba(20,66,37,1) 100% );}/*!sc*/
# .koznMz{font-size:20px;line-height:1.2;max-height:calc(7 * 24px);overflow:hidden;position:relative;min-height:calc(7 * 24px);}/*!sc*/
# .koznMz .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .koznMz:after{content:'';position:absolute;bottom:0;left:0;right:0;height:40.8px;background-image:linear-gradient( rgba(116,6,49,0) 0%, rgba(116,6,49,1) 100% );}/*!sc*/
# .bhpOhv{font-size:20px;line-height:1.2;max-height:calc(7 * 24px);overflow:hidden;position:relative;min-height:calc(7 * 24px);}/*!sc*/
# .bhpOhv .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .bhpOhv:after{content:'';position:absolute;bottom:0;left:0;right:0;height:40.8px;background-image:linear-gradient( rgba(107,119,128,0) 0%, rgba(107,119,128,1) 100% );}/*!sc*/
# .gbIeKX{font-size:20px;line-height:1.2;max-height:calc(7 * 24px);overflow:hidden;position:relative;min-height:calc(7 * 24px);}/*!sc*/
# .gbIeKX .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .gbIeKX:after{content:'';position:absolute;bottom:0;left:0;right:0;height:40.8px;background-image:linear-gradient( rgba(5,34,134,0) 0%, rgba(5,34,134,1) 100% );}/*!sc*/
# .fIAaMj{font-size:20px;line-height:1.2;max-height:calc(7 * 24px);overflow:hidden;position:relative;min-height:calc(7 * 24px);}/*!sc*/
# .fIAaMj .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .fIAaMj:after{content:'';position:absolute;bottom:0;left:0;right:0;height:40.8px;background-image:linear-gradient( rgba(217,60,35,0) 0%, rgba(217,60,35,1) 100% );}/*!sc*/
# .fpaTUC{color:rgb(107,119,128);font-size:14px;line-height:1.43;}/*!sc*/
# .fpaTUC .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;width:20.02px;}/*!sc*/
# .gA-DbwZ{font-weight:bold;font-size:14px;line-height:1.43;}/*!sc*/
# @media (min-width:376px){.gA-DbwZ{font-size:14px;}}/*!sc*/
# @media (min-width:570px){.gA-DbwZ{font-size:14px;}}/*!sc*/
# @media (min-width:768px){.gA-DbwZ{font-size:16px;}}/*!sc*/
# @media (min-width:376px){.gA-DbwZ{line-height:1.43;}}/*!sc*/
# @media (min-width:570px){.gA-DbwZ{line-height:1.43;}}/*!sc*/
# @media (min-width:768px){.gA-DbwZ{line-height:1.5;}}/*!sc*/
# .gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;width:20.02px;}/*!sc*/
# @media (min-width:376px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;}}/*!sc*/
# @media (min-width:570px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:20.02px;}}/*!sc*/
# @media (min-width:768px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;}}/*!sc*/
# @media (min-width:376px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:20.02px;}}/*!sc*/
# @media (min-width:570px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:20.02px;}}/*!sc*/
# @media (min-width:768px){.gA-DbwZ .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{width:24px;}}/*!sc*/
# data-styled.g9[id="Text__TextContainerBase-sc-1cait9d-1"]{content:"ijolhc,npfRF,nBoMt,bjqKkI,ilVROc,oVGDp,juzGEy,fkSzsq,jihWDw,cTGlQX,ensgkS,keMYfJ,dZyoXR,ccZuZv,kgxmNH,PopYU,kRjOhW,faLGMa,eZInmq,cYYbIw,hiOoPn,eAGsOb,koznMz,bhpOhv,gbIeKX,fIAaMj,fpaTUC,gA-DbwZ,"}/*!sc*/
# .gijRfk{padding:8px 16px 8px 16px;}/*!sc*/
# .kGavLk{padding:0 8px 0 0;}/*!sc*/
# .kGaqTU{padding:0 4px 0 0;}/*!sc*/
# .hJnrcP{padding:16px 0 0 0;}/*!sc*/
# .dtoUNs{padding:0 0 0 0;}/*!sc*/
# .gHVgOs{padding:0 0 4px 0;}/*!sc*/
# .hJnrea{padding:24px 0 0 0;}/*!sc*/
# .eHmMNv{padding:0 0 16px 0;}/*!sc*/
# .jVdBvQ{padding:8px 0 8px 0;}/*!sc*/
# .gJSrMw{padding:0 0 8px 0;}/*!sc*/
# .iNgXYN{padding:16px 0 24px 0;}/*!sc*/
# .kRVDgw{padding:8px 0 0 0;}/*!sc*/
# .jVdBvE{padding:4px 0 8px 0;}/*!sc*/
# .hQHLqo{padding:0 0 0 8px;}/*!sc*/
# .dbMfDQ{padding:4px 0 4px 0;}/*!sc*/
# .kRVDgk{padding:4px 0 0 0;}/*!sc*/
# .eRhLXC{padding:0 0 24px 0;}/*!sc*/
# .iNgXXA{padding:24px 0 24px 0;}/*!sc*/
# .gokgj{padding:0 16px 0 0;}/*!sc*/
# .gOaeFu{padding:8px 0 24px 0;}/*!sc*/
# .kftGdI{padding:16px 0 16px 0;}/*!sc*/
# .iBzWMU{padding:4px 48px 0 0;}/*!sc*/
# .kZJUGg{padding:4px 0 0 48px;}/*!sc*/
# data-styled.g10[id="Padding-sc-1tki7vp-0"]{content:"gijRfk,kGavLk,kGaqTU,hJnrcP,dtoUNs,gHVgOs,hJnrea,eHmMNv,jVdBvQ,gJSrMw,iNgXYN,kRVDgw,jVdBvE,hQHLqo,dbMfDQ,kRVDgk,eRhLXC,iNgXXA,gokgj,gOaeFu,kftGdI,iBzWMU,kZJUGg,"}/*!sc*/
# .TyxVS{-webkit-transition:box-shadow 0.1s,color 0.1s,border-color 0.2s,background-color 0.2s;transition:box-shadow 0.1s,color 0.1s,border-color 0.2s,background-color 0.2s;border-radius:24px;padding:1px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;width:48px;height:48px;border:1px solid rgb(232,233,234);background-color:rgb(255,255,255);outline:none;}/*!sc*/
# .TyxVS > .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# .TyxVS[class~='hover'],.TyxVS:hover{outline:none;border-color:transparent;box-shadow:0px 8px 16px 0px rgba(107,119,128,0.18),0px 2px 4px rgba(59,65,68,0.05);}/*!sc*/
# .TyxVS[class~='active'],.TyxVS:active,.TyxVS:active:hover{border-color:transparent;box-shadow:none;background-color:rgb(107,119,128);color:rgb(255,255,255);}/*!sc*/
# .TyxVS[class~='active'] path,.TyxVS:active path,.TyxVS:active:hover path{fill:rgb(255,255,255);}/*!sc*/
# .TyxVS:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .TUpTu{-webkit-transition:box-shadow 0.1s,color 0.1s,border-color 0.2s,background-color 0.2s;transition:box-shadow 0.1s,color 0.1s,border-color 0.2s,background-color 0.2s;border-radius:24px;padding:1px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;width:24px;height:24px;border:1px solid rgb(232,233,234);background-color:rgb(255,255,255);outline:none;}/*!sc*/
# .TUpTu > .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# .TUpTu[class~='hover'],.TUpTu:hover{outline:none;border-color:transparent;box-shadow:0px 8px 16px 0px rgba(107,119,128,0.18),0px 2px 4px rgba(59,65,68,0.05);}/*!sc*/
# .TUpTu[class~='active'],.TUpTu:active,.TUpTu:active:hover{border-color:transparent;box-shadow:none;background-color:rgb(107,119,128);color:rgb(255,255,255);}/*!sc*/
# .TUpTu[class~='active'] path,.TUpTu:active path,.TUpTu:active:hover path{fill:rgb(255,255,255);}/*!sc*/
# .TUpTu:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .iBXyOi{-webkit-transition:box-shadow 0.1s,color 0.1s,border-color 0.2s,background-color 0.2s;transition:box-shadow 0.1s,color 0.1s,border-color 0.2s,background-color 0.2s;border-radius:24px;padding:1px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;width:32px;height:32px;border:1px solid rgb(232,233,234);background-color:rgb(255,255,255);outline:none;}/*!sc*/
# .iBXyOi > .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# .iBXyOi[class~='hover'],.iBXyOi:hover{outline:none;border-color:transparent;box-shadow:0px 8px 16px 0px rgba(107,119,128,0.18),0px 2px 4px rgba(59,65,68,0.05);}/*!sc*/
# .iBXyOi[class~='active'],.iBXyOi:active,.iBXyOi:active:hover{border-color:transparent;box-shadow:none;background-color:rgb(107,119,128);color:rgb(255,255,255);}/*!sc*/
# .iBXyOi[class~='active'] path,.iBXyOi:active path,.iBXyOi:active:hover path{fill:rgb(255,255,255);}/*!sc*/
# .iBXyOi:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g11[id="FloatingActionButton-sc-6olq4f-0"]{content:"TyxVS,TUpTu,iBXyOi,"}/*!sc*/
# .giAiEJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:auto;-webkit-overflow-scrolling:touch;}/*!sc*/
# .bPNugb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:auto;-webkit-overflow-scrolling:touch;}/*!sc*/
# @media (max-width:47.9375em){.bPNugb{display:block;}}/*!sc*/
# data-styled.g12[id="FlexContainers__Rows-zvngfq-0"]{content:"giAiEJ,bPNugb,"}/*!sc*/
# .eWBQcF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:start;-webkit-justify-content:start;-ms-flex-pack:start;justify-content:start;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;}/*!sc*/
# @media (max-width:47.9375em){.eWBQcF{display:block;}}/*!sc*/
# .eCjeDf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# .hLuLYV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media (max-width:47.9375em){.hLuLYV{display:block;}}/*!sc*/
# data-styled.g14[id="FlexContainers__Columns-zvngfq-2"]{content:"eWBQcF,eCjeDf,hLuLYV,"}/*!sc*/
# .kRfxNx{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;-webkit-text-decoration:none;text-decoration:none;font-size:16px;line-height:1.5;padding:8px 16px;outline:none;}/*!sc*/
# .kRfxNx path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .kRfxNx .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .kRfxNx::-moz-focus-inner{border:0;}/*!sc*/
# .kRfxNx[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .kRfxNx:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g22[id="ButtonBase-sc-14ooajz-0"]{content:"kRfxNx,"}/*!sc*/
# .iSYPov{line-height:1;color:inherit;}/*!sc*/
# .iSYPov:hover,.iSYPov:focus{color:rgb(0,120,130);}/*!sc*/
# .iSYPov:hover path,.iSYPov:focus path{fill:rgb(0,120,130);}/*!sc*/
# .jPioDE{line-height:1;color:inherit;}/*!sc*/
# .ffVPDP{line-height:1;color:inherit;}/*!sc*/
# .ffVPDP:hover,.ffVPDP:focus{color:rgb(255,255,255);}/*!sc*/
# .ffVPDP:hover path,.ffVPDP:focus path{fill:rgb(255,255,255);}/*!sc*/
# data-styled.g30[id="UiButton-r41csk-0"]{content:"iSYPov,jPioDE,ffVPDP,"}/*!sc*/
# .iLsXMy{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;-webkit-text-decoration:none;text-decoration:none;font-size:16px;line-height:1.5;padding:8px 16px;outline:none;color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:rgb(205,209,212);}/*!sc*/
# .iLsXMy path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .iLsXMy .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .iLsXMy::-moz-focus-inner{border:0;}/*!sc*/
# .iLsXMy[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .iLsXMy:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .iLsXMy:hover,.iLsXMy[class~='hover']{color:rgb(59,65,68);background-color:rgb(232,233,234);border-color:transparent;}/*!sc*/
# .iLsXMy[class~='focus'],.iLsXMy:focus{color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:rgb(107,119,128);outline:none;}/*!sc*/
# .iLsXMy[class~='focus']:focus-visible,.iLsXMy:focus:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .iLsXMy[class~='active'],.iLsXMy:active{color:rgb(255,255,255);background-color:rgb(107,119,128);border-color:transparent;}/*!sc*/
# .iLsXMy[class~='active'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.iLsXMy:active .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(255,255,255);}/*!sc*/
# .iLsXMy[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);}/*!sc*/
# .iLsXMy[disabled] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(205,209,212);}/*!sc*/
# data-styled.g34[id="Button-sc-1ea9wz-0"]{content:"iLsXMy,"}/*!sc*/
# .lRdPd{width:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.lRdPd{width:100%;}}/*!sc*/
# @media (min-width:570px){.lRdPd{width:100%;}}/*!sc*/
# @media (min-width:768px){.lRdPd{width:100%;}}/*!sc*/
# @media (min-width:993px){.lRdPd{width:66.60000000000001%;}}/*!sc*/
# .kFYOJA{width:70%;-webkit-order:1;-ms-flex-order:1;order:1;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.kFYOJA{width:70%;}}/*!sc*/
# @media (min-width:570px){.kFYOJA{width:60%;}}/*!sc*/
# @media (min-width:768px){.kFYOJA{width:66%;}}/*!sc*/
# @media (min-width:993px){.kFYOJA{width:66%;}}/*!sc*/
# .brRjqZ{width:0%;-webkit-order:2;-ms-flex-order:2;order:2;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.brRjqZ{width:0%;}}/*!sc*/
# @media (min-width:570px){.brRjqZ{width:0%;}}/*!sc*/
# @media (min-width:768px){.brRjqZ{width:34%;}}/*!sc*/
# @media (min-width:993px){.brRjqZ{width:34%;}}/*!sc*/
# .jABNPB{width:65%;-webkit-order:4;-ms-flex-order:4;order:4;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.jABNPB{width:65%;}}/*!sc*/
# @media (min-width:570px){.jABNPB{width:66%;}}/*!sc*/
# @media (min-width:768px){.jABNPB{width:0%;}}/*!sc*/
# @media (min-width:993px){.jABNPB{width:0%;}}/*!sc*/
# @media (min-width:376px){.jABNPB{display:block;}}/*!sc*/
# @media (min-width:570px){.jABNPB{display:block;}}/*!sc*/
# @media (min-width:768px){.jABNPB{display:none;}}/*!sc*/
# @media (min-width:993px){.jABNPB{display:none;}}/*!sc*/
# .eRTUAw{width:33%;-webkit-order:5;-ms-flex-order:5;order:5;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.eRTUAw{width:33%;}}/*!sc*/
# @media (min-width:570px){.eRTUAw{width:33%;}}/*!sc*/
# @media (min-width:768px){.eRTUAw{width:0%;}}/*!sc*/
# @media (min-width:993px){.eRTUAw{width:0%;}}/*!sc*/
# @media (min-width:376px){.eRTUAw{display:block;}}/*!sc*/
# @media (min-width:570px){.eRTUAw{display:block;}}/*!sc*/
# @media (min-width:768px){.eRTUAw{display:none;}}/*!sc*/
# @media (min-width:993px){.eRTUAw{display:none;}}/*!sc*/
# .bNdNuM{-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# .gChOjS{display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# .dzZMcw{width:0%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:none;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.dzZMcw{width:0%;}}/*!sc*/
# @media (min-width:570px){.dzZMcw{width:0%;}}/*!sc*/
# @media (min-width:768px){.dzZMcw{width:0%;}}/*!sc*/
# @media (min-width:993px){.dzZMcw{width:33.4%;}}/*!sc*/
# @media (min-width:376px){.dzZMcw{display:none;}}/*!sc*/
# @media (min-width:570px){.dzZMcw{display:none;}}/*!sc*/
# @media (min-width:768px){.dzZMcw{display:none;}}/*!sc*/
# @media (min-width:993px){.dzZMcw{display:block;}}/*!sc*/
# .iMcyLD{width:50%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# .dBOwEV{width:50%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.dBOwEV{width:50%;}}/*!sc*/
# @media (min-width:570px){.dBOwEV{width:50%;}}/*!sc*/
# @media (min-width:768px){.dBOwEV{width:25%;}}/*!sc*/
# .dtaNiz{width:50%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.dtaNiz{width:50%;}}/*!sc*/
# @media (min-width:570px){.dtaNiz{width:50%;}}/*!sc*/
# @media (min-width:768px){.dtaNiz{width:50%;}}/*!sc*/
# @media (min-width:993px){.dtaNiz{width:25%;}}/*!sc*/
# .gmlMqc{width:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.gmlMqc{width:100%;}}/*!sc*/
# @media (min-width:570px){.gmlMqc{width:60%;}}/*!sc*/
# .cnupPC{width:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.cnupPC{width:100%;}}/*!sc*/
# @media (min-width:570px){.cnupPC{width:40%;}}/*!sc*/
# .bhqXOu{width:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.bhqXOu{width:100%;}}/*!sc*/
# @media (min-width:570px){.bhqXOu{width:33%;}}/*!sc*/
# .ixBhxi{width:96%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.ixBhxi{width:96%;}}/*!sc*/
# @media (min-width:570px){.ixBhxi{width:48%;}}/*!sc*/
# @media (min-width:768px){.ixBhxi{width:32%;}}/*!sc*/
# @media (min-width:993px){.ixBhxi{width:25%;}}/*!sc*/
# .fpcyVU{width:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.fpcyVU{width:100%;}}/*!sc*/
# @media (min-width:570px){.fpcyVU{width:100%;}}/*!sc*/
# @media (min-width:768px){.fpcyVU{width:66.66666666666666%;}}/*!sc*/
# .kKYzaA{width:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.kKYzaA{width:100%;}}/*!sc*/
# @media (min-width:570px){.kKYzaA{width:33.33333333333333%;}}/*!sc*/
# data-styled.g53[id="Grid__CellBox-sc-144isrp-0"]{content:"lRdPd,kFYOJA,brRjqZ,jABNPB,eRTUAw,bNdNuM,gChOjS,dzZMcw,iMcyLD,dBOwEV,dtaNiz,gmlMqc,cnupPC,bhqXOu,ixBhxi,fpcyVU,kKYzaA,"}/*!sc*/
# .bQSVOQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:-8px;margin-right:-8px;margin-top:-16px;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# .bQSVOQ > .Grid__CellBox-sc-144isrp-0{border-style:solid;border-color:transparent;border-width:16px 8px 0px 8px;}/*!sc*/
# .wFoMI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:0;margin-right:0;margin-top:-4px;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# @media (min-width:376px){.wFoMI{margin-left:-2px;}}/*!sc*/
# @media (min-width:570px){.wFoMI{margin-left:-2px;}}/*!sc*/
# @media (min-width:376px){.wFoMI{margin-right:-2px;}}/*!sc*/
# @media (min-width:570px){.wFoMI{margin-right:-2px;}}/*!sc*/
# .wFoMI > .Grid__CellBox-sc-144isrp-0{border-style:solid;border-color:transparent;border-width:4px 2px 0px 2px;}/*!sc*/
# .eoSlgA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:0;margin-right:0;margin-top:-4px;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;overflow-x:auto;-webkit-overflow-scrolling:touch;}/*!sc*/
# @media (min-width:376px){.eoSlgA{margin-left:-2px;}}/*!sc*/
# @media (min-width:570px){.eoSlgA{margin-left:-2px;}}/*!sc*/
# @media (min-width:376px){.eoSlgA{margin-right:-2px;}}/*!sc*/
# @media (min-width:570px){.eoSlgA{margin-right:-2px;}}/*!sc*/
# .eoSlgA > .Grid__CellBox-sc-144isrp-0{border-style:solid;border-color:transparent;border-width:4px 2px 0px 2px;}/*!sc*/
# .iqgnOs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:-8px;margin-right:-8px;margin-top:-16px;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;overflow-x:auto;-webkit-overflow-scrolling:touch;}/*!sc*/
# .iqgnOs > .Grid__CellBox-sc-144isrp-0{border-style:solid;border-color:transparent;border-width:16px 8px 0px 8px;}/*!sc*/
# data-styled.g54[id="Grid__GridContainer-sc-144isrp-1"]{content:"bQSVOQ,wFoMI,eoSlgA,iqgnOs,"}/*!sc*/
# .bAQLyZ{object-fit:cover;object-fit:cover;width:100%;height:100%;}/*!sc*/
# .dkmneJ{width:24px;height:24px;}/*!sc*/
# .hPjFaC{object-fit:cover;width:100%;height:100%;}/*!sc*/
# .bALjLo{object-fit:cover;width:100%;height:200px;}/*!sc*/
# .ckrOth{width:auto;height:16px;}/*!sc*/
# .kocGyJ{width:26px;height:26px;}/*!sc*/
# .cOExqt{width:20px;height:20px;}/*!sc*/
# .gxFFhh{width:30px;height:30px;}/*!sc*/
# .kCoHRx{width:32px;height:32px;}/*!sc*/
# .eTqvtx{width:28px;height:28px;}/*!sc*/
# .lgUmCZ{width:auto;height:auto;}/*!sc*/
# data-styled.g56[id="Image__ImageContainer-sc-1motiir-0"]{content:"bAQLyZ,dkmneJ,hPjFaC,bALjLo,ckrOth,kocGyJ,cOExqt,gxFFhh,kCoHRx,eTqvtx,lgUmCZ,"}/*!sc*/
# .eWkDYx{width:70px;height:24px;display:inline-block;line-height:0;}/*!sc*/
# .eWkDYx .svg{width:70px;}/*!sc*/
# .eWkDYx .svg{height:24px;}/*!sc*/
# data-styled.g58[id="getSvgContainer__SvgContainer-sc-9w90nz-0"]{content:"eWkDYx,"}/*!sc*/
# .ktWWoP{height:24px;}/*!sc*/
# .ktWWoP .svg{height:24px;}/*!sc*/
# .cKFaMj{height:20px;}/*!sc*/
# .cKFaMj .svg{height:20px;}/*!sc*/
# .btcMsz{height:30px;}/*!sc*/
# .btcMsz .svg{height:30px;}/*!sc*/
# .hOJdqX{height:32px;}/*!sc*/
# .hOJdqX .svg{height:32px;}/*!sc*/
# .hNpERL{height:28px;}/*!sc*/
# .hNpERL .svg{height:28px;}/*!sc*/
# data-styled.g59[id="getSvgContainer__StyledImage-sc-9w90nz-1"]{content:"ktWWoP,cKFaMj,btcMsz,hOJdqX,hNpERL,"}/*!sc*/
# .gSLuwD{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .gSLuwD:hover{-webkit-text-decoration:underline;text-decoration:underline;color:rgb(0,69,75);}/*!sc*/
# .iKTbuz{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .iKTbuz:hover{-webkit-text-decoration:underline;text-decoration:underline;color:rgb(0,69,75);}/*!sc*/
# data-styled.g60[id="Anchor__StyledText-sc-5lya7g-0"]{content:"gSLuwD,iKTbuz,"}/*!sc*/
# .euBOac{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .euBOac:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .gLFHbk{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .gLFHbk:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g61[id="Anchor__StyledAnchor-sc-5lya7g-1"]{content:"euBOac,gLFHbk,"}/*!sc*/
# .bArfXM{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;height:auto;width:auto;max-width:35%;margin-right:auto;display:none;}/*!sc*/
# @media (max-width:47.9375em){.bArfXM{display:block;}}/*!sc*/
# data-styled.g62[id="BackToSearchLink__BackToSearchLinkContainer-p8pras-0"]{content:"bArfXM,"}/*!sc*/
# .fNzzge > div:last-child{margin-left:-6px;}/*!sc*/
# data-styled.g63[id="BackToSearchLink__StyledMediaBlock-p8pras-1"]{content:"fNzzge,"}/*!sc*/
# .dctVKe path{stroke:rgb(0,120,130);stroke-width:0.5;}/*!sc*/
# data-styled.g64[id="BackToSearchLink__BackToSearchIcon-p8pras-2"]{content:"dctVKe,"}/*!sc*/
# .eAlroL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:64px;margin:0;padding:0 16px 0 16px;padding:0 calc(16px + env(safe-area-inset-right)) 0 calc(16px + env(safe-area-inset-left));background-color:rgb(255,255,255);position:relative;z-index:100;font-size:15px;border-bottom:1px solid rgb(232,233,234);}/*!sc*/
# @media (max-width:62em){.eAlroL{padding:0 12px;}}/*!sc*/
# data-styled.g65[id="Navbar__Nav-sky7mr-0"]{content:"eAlroL,"}/*!sc*/
# .ZwySm{margin-left:16px;padding:0 4px;background-color:rgb(255,255,255);}/*!sc*/
# @media (max-width:62em){.ZwySm{margin-right:-10px;margin-left:2px;}}/*!sc*/
# data-styled.g66[id="Navbar__NavbarMobileMenuToggle-sky7mr-1"]{content:"ZwySm,"}/*!sc*/
# .kQJAbP{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding:16px 24px 16px 0;}/*!sc*/
# @media (max-width:62em){.kQJAbP{padding:12px 12px 12px 6px;}}/*!sc*/
# @media (max-width:47.9375em){.kQJAbP{position:absolute;left:50%;-webkit-transform:translate(-50%,0);-ms-transform:translate(-50%,0);transform:translate(-50%,0);}}/*!sc*/
# data-styled.g67[id="Navbar__LogoContainer-sky7mr-2"]{content:"kQJAbP,"}/*!sc*/
# .kbckwe{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justift-content:center;-ms-flex-pack:center;justift-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:100%;}/*!sc*/
# data-styled.g69[id="Navbar__IconContainer-sky7mr-4"]{content:"kbckwe,"}/*!sc*/
# .iMHbRw{color:rgb(59,65,68);-webkit-transition:background 0.15s ease-in-out;transition:background 0.15s ease-in-out;position:relative;}/*!sc*/
# .iMHbRw > a,.iMHbRw > span,.iMHbRw > button:not(.Button-sc-1ea9wz-0){cursor:pointer;padding:8px 16px 8px 16px;color:rgb(59,65,68);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:8px;background-color:transparent;}/*!sc*/
# .iMHbRw > a:focus svg path,.iMHbRw > span:focus svg path,.iMHbRw > button:not(.Button-sc-1ea9wz-0):focus svg path{fill:rgb(59,65,68);}/*!sc*/
# .iMHbRw svg{margin-top:-1px;}/*!sc*/
# .iMHbRw > span{cursor:default;}/*!sc*/
# .iMHbRw:hover > a,.iMHbRw:hover > span,.iMHbRw:hover > button:not(.Button-sc-1ea9wz-0){color:rgb(255,255,255);background-color:rgb(0,120,130);}/*!sc*/
# .iMHbRw:hover > a svg path,.iMHbRw:hover > span svg path,.iMHbRw:hover > button:not(.Button-sc-1ea9wz-0) svg path{fill:rgb(255,255,255);}/*!sc*/
# .iMHbRw:hover > ul{display:block;}/*!sc*/
# .iMHbRw ul{display:none;position:absolute;top:45px;background:rgb(255,255,255);border-radius:4px;box-shadow:0 2px 4px 0 rgba(59,65,68,0.5);padding:4px 0;}/*!sc*/
# .iMHbRw ul a,.iMHbRw ul button{color:rgb(59,65,68);white-space:nowrap;display:block;}/*!sc*/
# .iMHbRw ul a:hover,.iMHbRw ul button:hover{color:rgb(59,65,68);background-color:rgb(232,233,234);}/*!sc*/
# .iMHbRw ul::before{display:block;position:absolute;content:'';width:100%;height:15px;top:-15px;}/*!sc*/
# @media (max-width:62em){.iMHbRw{display:none;}}/*!sc*/
# data-styled.g75[id="NavbarItem__StyledNavbarItem-sc-1kjsgse-0"]{content:"iMHbRw,"}/*!sc*/
# .jvZEPV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:4px;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;}/*!sc*/
# @media (min-width:1060px){}/*!sc*/
# @media (min-width:1240px){}/*!sc*/
# data-styled.g77[id="NavbarSection-gp9p9l-0"]{content:"jvZEPV,"}/*!sc*/
# .fgHPbp{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;-webkit-text-decoration:none;text-decoration:none;font-size:16px;line-height:1.5;padding:8px 16px;outline:none;color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:transparent;}/*!sc*/
# .fgHPbp path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .fgHPbp .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0{height:24px;width:24px;}/*!sc*/
# .fgHPbp::-moz-focus-inner{border:0;}/*!sc*/
# .fgHPbp[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .fgHPbp:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .fgHPbp .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(59,65,68);}/*!sc*/
# .fgHPbp[class~='hover'],.fgHPbp:hover{color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transprant;}/*!sc*/
# .fgHPbp[class~='hover'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.fgHPbp:hover .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(255,255,255);}/*!sc*/
# .fgHPbp[class~='focus'],.fgHPbp:focus{color:rgb(0,120,130);border-color:rgb(0,120,130);}/*!sc*/
# .fgHPbp[class~='focus'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.fgHPbp:focus .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(0,120,130);}/*!sc*/
# .fgHPbp[class~='active'],.fgHPbp:active{color:rgb(59,65,68);background-color:rgb(232,233,234);border-color:transparent;box-shadow:none;}/*!sc*/
# .fgHPbp[class~='active'] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path,.fgHPbp:active .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(59,65,68);}/*!sc*/
# .fgHPbp[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);box-shadow:none;}/*!sc*/
# .fgHPbp[disabled] .getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 path{fill:rgb(205,209,212);}/*!sc*/
# data-styled.g80[id="GlobalNavigationButton-x0gdrd-0"]{content:"fgHPbp,"}/*!sc*/
# ...
# "</i></blockquote></div></div></div><div class="FlexContainers__Row-zvngfq-1 Card__CardFooter-qyhhuy-3 cbQJVz"><div class="MediaBlock__MediaContainer-skmvlj-0 eIkmHi"><div class="MediaBlock__MediaContent-skmvlj-1 BVZzV"><div><div aria-label="Like Review" class="Box__BoxElement-sc-1f5rw0h-0 bsjsJO BoxButton-sc-12vrxun-0 limZBd UiButton-r41csk-0 ffVPDP" data-testid="wls-review-like-button" role="button" tabindex="0"><div class="MediaBlock__MediaContainer-skmvlj-0 eIkmHi"><div class="getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 hnYFju"><svg aria-hidden="true" aria-label="" class="svg" role="img" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M15.96 29.26c-7.345 0-13.3-5.955-13.3-13.3 0-7.345 5.955-13.3 13.3-13.3 7.345 0 13.3 5.955 13.3 13.3 0 7.345-5.955 13.3-13.3 13.3zm0-2.66c5.876 0 10.64-4.764 10.64-10.64S21.836 5.32 15.96 5.32 5.32 10.084 5.32 15.96 10.084 26.6 15.96 26.6zM12.048 9.602a1.995 1.995 0 1 1 0 3.99 1.995 1.995 0 0 1 0-3.99zm7.824 0a1.995 1.995 0 1 1 0 3.99 1.995 1.995 0 0 1 0-3.99zm-11.23 7.174a1.33 1.33 0 0 1 2.66 0 4.658 4.658 0 1 0 9.316 0 1.33 1.33 0 0 1 2.66 0 7.318 7.318 0 0 1-14.636 0z" fill="#869099"></path></svg></div><div class="MediaBlock__MediaContent-skmvlj-1 dwmuOU"><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 bjqKkI">0</div></div></div></div></div></div><div aria-label="Flag Review" class="Box__BoxElement-sc-1f5rw0h-0 bsjsJO BoxButton-sc-12vrxun-0 fAXlbl UiButton-r41csk-0 ffVPDP" data-testid="wls-review-flag-button" role="button" tabindex="0">Flag</div></div></div></div></div></div></div></li><li class="Grid__CellBox-sc-144isrp-0 ixBhxi ResponsiveSlider__ScrollItem-k9sku0-6 kApQXz" width="96%,96%,48%,32%,25%"><div class="Grid__CellBox-sc-144isrp-0 bNdNuM" width=""><div data-testid="wls-review-card"><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 npfRF" color="inverse"><div class="Box__BoxElement-sc-1f5rw0h-0 bsjsJO BoxButton-sc-12vrxun-0 limZBd FlexContainers__Rows-zvngfq-0 bPNugb Card-qyhhuy-0 eXnoA-d UserReviewCard__UserReviewCardContainer-sc-72r1bt-1 faIHaB" role="button" spacing="looser" tabindex="0"><div class="FlexContainers__Row-zvngfq-1 Card__CardHeader-qyhhuy-1 godnwf"><div class="MediaBlock__MediaContainer-skmvlj-0 eIkmHi"><div class="CircleBox-n5nj62-0 jRatGg" size="32"><div class="getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 bosPhI"><svg aria-hidden="true" aria-label="" class="svg" role="img" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M11.598 10.564a4.485 4.485 0 1 0 8.97 0 4.485 4.485 0 0 0-8.97 0zm-2.66 0a7.145 7.145 0 1 1 14.29 0 7.145 7.145 0 0 1-14.29 0zm7.146 7.145c-4.021 0-7.318 3.238-7.318 6.938v.609h14.635v-.609c0-3.7-3.297-6.938-7.317-6.938zm0-2.66c5.424 0 9.977 4.365 9.977 9.598v3.269H6.106v-3.269c0-5.234 4.552-9.598 9.978-9.598z" fill="#869099"></path></svg></div></div><div class="MediaBlock__MediaContent-skmvlj-1 edhurL"><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 kRjOhW" title="Trulia User">Trulia User</div><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 cYYbIw"><ul class="List__ListContainer-sc-8uj508-0 ctIOhZ" role="presentation"><li title="Resident">Resident</li><li title="1y ago">1y ago</li></ul></div></div></div></div><div class="FlexContainers__Row-zvngfq-1 Card__CardContent-qyhhuy-2 jJdFii"><div class="Padding-sc-1tki7vp-0 iNgXXA"><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 fIAaMj"><blockquote class="UserReviewCard__StyledBlockquote-sc-72r1bt-0 gBqrzJ"><i>"Dog owners would like how dog friendly the town is. Coffee shops, restaurants, and breweries all allow dogs. Dog owners would hate how there are barely any public trash cans to dispose of dog poop and also that other dog owners do not pick up after their dogs. "</i></blockquote></div></div></div><div class="FlexContainers__Row-zvngfq-1 Card__CardFooter-qyhhuy-3 cbQJVz"><div class="MediaBlock__MediaContain ...
# Not a lot of kids
# Not a variety of schools
# More for young adults                  "</i></blockquote></div></div></div><div class="FlexContainers__Row-zvngfq-1 Card__CardFooter-qyhhuy-3 cbQJVz"><div class="MediaBlock__MediaContainer-skmvlj-0 eIkmHi"><div class="MediaBlock__MediaContent-skmvlj-1 BVZzV"><div><div aria-label="Like Review" class="Box__BoxElement-sc-1f5rw0h-0 bsjsJO BoxButton-sc-12vrxun-0 limZBd UiButton-r41csk-0 ffVPDP" data-testid="wls-review-like-button" role="button" tabindex="0"><div class="MediaBlock__MediaContainer-skmvlj-0 eIkmHi"><div class="getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 hnYFju"><svg aria-hidden="true" aria-label="" class="svg" role="img" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M15.96 29.26c-7.345 0-13.3-5.955-13.3-13.3 0-7.345 5.955-13.3 13.3-13.3 7.345 0 13.3 5.955 13.3 13.3 0 7.345-5.955 13.3-13.3 13.3zm0-2.66c5.876 0 10.64-4.764 10.64-10.64S21.836 5.32 15.96 5.32 5.32 10.084 5.32 15.96 10.084 26.6 15.96 26.6zM12.048 9.602a1.995 1.995 0 1 1 0 3.99 1.995 1.995 0 0 1 0-3.99zm7.824 0a1.995 1.995 0 1 1 0 3.99 1.995 1.995 0 0 1 0-3.99zm-11.23 7.174a1.33 1.33 0 0 1 2.66 0 4.658 4.658 0 1 0 9.316 0 1.33 1.33 0 0 1 2.66 0 7.318 7.318 0 0 1-14.636 0z" fill="#869099"></path></svg></div><div class="MediaBlock__MediaContent-skmvlj-1 dwmuOU"><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 bjqKkI">1</div></div></div></div></div></div><div aria-label="Flag Review" class="Box__BoxElement-sc-1f5rw0h-0 bsjsJO BoxButton-sc-12vrxun-0 fAXlbl UiButton-r41csk-0 ffVPDP" data-testid="wls-review-flag-button" role="button" tabindex="0">Flag</div></div></div></div></div></div></div></li><li class="Grid__CellBox-sc-144isrp-0 ixBhxi ResponsiveSlider__ScrollItem-k9sku0-6 kApQXz" width="96%,96%,48%,32%,25%"><div class="Grid__CellBox-sc-144isrp-0 bNdNuM" width=""><div data-testid="wls-review-card"><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 npfRF" color="inverse"><div class="Box__BoxElement-sc-1f5rw0h-0 bsjsJO BoxButton-sc-12vrxun-0 limZBd FlexContainers__Rows-zvngfq-0 bPNugb Card-qyhhuy-0 eXnoA-d UserReviewCard__UserReviewCardContainer-sc-72r1bt-1 hbyoNT" role="button" spacing="looser" tabindex="0"><div class="FlexContainers__Row-zvngfq-1 Card__CardHeader-qyhhuy-1 godnwf"><div class="MediaBlock__MediaContainer-skmvlj-0 eIkmHi"><div class="CircleBox-n5nj62-0 jRatGg" size="32"><div class="getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 bosPhI"><svg aria-hidden="true" aria-label="" class="svg" role="img" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M11.598 10.564a4.485 4.485 0 1 0 8.97 0 4.485 4.485 0 0 0-8.97 0zm-2.66 0a7.145 7.145 0 1 1 14.29 0 7.145 7.145 0 0 1-14.29 0zm7.146 7.145c-4.021 0-7.318 3.238-7.318 6.938v.609h14.635v-.609c0-3.7-3.297-6.938-7.317-6.938zm0-2.66c5.424 0 9.977 4.365 9.977 9.598v3.269H6.106v-3.269c0-5.234 4.552-9.598 9.978-9.598z" fill="#869099"></path></svg></div></div><div class="MediaBlock__MediaContent-skmvlj-1 edhurL"><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 kRjOhW" title="Trulia User">Trulia User</div><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 cYYbIw"><ul class="List__ListContainer-sc-8uj508-0 ctIOhZ" role="presentation"><li title="Resident">Resident</li><li title="1y ago">1y ago</li></ul></div></div></div></div><div class="FlexContainers__Row-zvngfq-1 Card__CardContent-qyhhuy-2 jJdFii"><div class="Padding-sc-1tki7vp-0 iNgXXA"><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 eAGsOb"><blockquote class="UserReviewCard__StyledBlockquote-sc-72r1bt-0 gBqrzJ"><i>"There are different pockets of NP that are more family-friendly than others. Be careful and visit the neighboring blocks to get a feel if there are more residential, family homes or apartment complexes. There can be a lot of transients in the area, as well, the closer you get to University and 30th. "</i></blockquote></div></div></div><div class="FlexContainers__Row- ...
# Thursday farmers markets
# Great food
# kid friendly restaurants
# Community vibe
# Festivals
# SoNo chili cook off "</i></blockquote></div></div></div><div class="FlexContainers__Row-zvngfq-1 Card__CardFooter-qyhhuy-3 cbQJVz"><div class="MediaBlock__MediaContainer-skmvlj-0 eIkmHi"><div class="MediaBlock__MediaContent-skmvlj-1 BVZzV"><div><div aria-label="Like Review" class="Box__BoxElement-sc-1f5rw0h-0 bsjsJO BoxButton-sc-12vrxun-0 limZBd UiButton-r41csk-0 ffVPDP" data-testid="wls-review-like-button" role="button" tabindex="0"><div class="MediaBlock__MediaContainer-skmvlj-0 eIkmHi"><div class="getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 hnYFju"><svg aria-hidden="true" aria-label="" class="svg" role="img" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M15.96 29.26c-7.345 0-13.3-5.955-13.3-13.3 0-7.345 5.955-13.3 13.3-13.3 7.345 0 13.3 5.955 13.3 13.3 0 7.345-5.955 13.3-13.3 13.3zm0-2.66c5.876 0 10.64-4.764 10.64-10.64S21.836 5.32 15.96 5.32 5.32 10.084 5.32 15.96 10.084 26.6 15.96 26.6zM12.048 9.602a1.995 1.995 0 1 1 0 3.99 1.995 1.995 0 0 1 0-3.99zm7.824 0a1.995 1.995 0 1 1 0 3.99 1.995 1.995 0 0 1 0-3.99zm-11.23 7.174a1.33 1.33 0 0 1 2.66 0 4.658 4.658 0 1 0 9.316 0 1.33 1.33 0 0 1 2.66 0 7.318 7.318 0 0 1-14.636 0z" fill="#869099"></path></svg></div><div class="MediaBlock__MediaContent-skmvlj-1 dwmuOU"><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 bjqKkI">0</div></div></div></div></div></div><div aria-label="Flag Review" class="Box__BoxElement-sc-1f5rw0h-0 bsjsJO BoxButton-sc-12vrxun-0 fAXlbl UiButton-r41csk-0 ffVPDP" data-testid="wls-review-flag-button" role="button" tabindex="0">Flag</div></div></div></div></div></div></div></li><li class="Grid__CellBox-sc-144isrp-0 ixBhxi ResponsiveSlider__ScrollItem-k9sku0-6 kApQXz" width="96%,96%,48%,32%,25%"><div class="Grid__CellBox-sc-144isrp-0 bNdNuM" width=""><div data-testid="wls-review-card"><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 npfRF" color="inverse"><div class="Box__BoxElement-sc-1f5rw0h-0 bsjsJO BoxButton-sc-12vrxun-0 limZBd FlexContainers__Rows-zvngfq-0 bPNugb Card-qyhhuy-0 eXnoA-d UserReviewCard__UserReviewCardContainer-sc-72r1bt-1 ilIEaY" role="button" spacing="looser" tabindex="0"><div class="FlexContainers__Row-zvngfq-1 Card__CardHeader-qyhhuy-1 godnwf"><div class="MediaBlock__MediaContainer-skmvlj-0 eIkmHi"><div class="CircleBox-n5nj62-0 jRatGg" size="32"><div class="getUiSvgContainer__SvgContainer-sc-1cdn1ln-0 bosPhI"><svg aria-hidden="true" aria-label="" class="svg" role="img" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M11.598 10.564a4.485 4.485 0 1 0 8.97 0 4.485 4.485 0 0 0-8.97 0zm-2.66 0a7.145 7.145 0 1 1 14.29 0 7.145 7.145 0 0 1-14.29 0zm7.146 7.145c-4.021 0-7.318 3.238-7.318 6.938v.609h14.635v-.609c0-3.7-3.297-6.938-7.317-6.938zm0-2.66c5.424 0 9.977 4.365 9.977 9.598v3.269H6.106v-3.269c0-5.234 4.552-9.598 9.978-9.598z" fill="#869099"></path></svg></div></div><div class="MediaBlock__MediaContent-skmvlj-1 edhurL"><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 kRjOhW" title="Trulia User">Trulia User</div><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 cYYbIw"><ul class="List__ListContainer-sc-8uj508-0 ctIOhZ" role="presentation"><li title="Resident">Resident</li><li title="2y ago">2y ago</li></ul></div></div></div></div><div class="FlexContainers__Row-zvngfq-1 Card__CardContent-qyhhuy-2 jJdFii"><div class="Padding-sc-1tki7vp-0 iNgXXA"><div class="Text__TextBase-sc-1cait9d-0-div Text__TextContainerBase-sc-1cait9d-1 koznMz"><blockquote class="UserReviewCard__StyledBlockquote-sc-72r1bt-0 gBqrzJ"><i>"I’m not really aware of any community events. It’s the accessibility to all things great in SD that make it such a great place. "</i></blockquote></div></div></div><div class="FlexContainers__Row-zvngfq-1 Card__CardFooter-qyhhuy-3 cbQJVz"><div class="MediaBlock__MediaContainer-skmvlj-0 eIkmHi"><div class="MediaBlock__MediaContent-skmvlj-1 BVZzV"><div><div aria-label="Like Review" class ...
#           function initTracking(pageviewPayload) {
#     let count = 0;
#     const MAX_COUNT = 100;
#     window.s = window.s || {};
#     window.trulia = window.trulia || {};
#     window.trulia.dataLayer = window.trulia.dataLayer || {};
#     window.trulia.dataLayer.referrer = document.referrer;
#
#     function listenersDefined() {
#       const listeners = window.trulia.dataLayer.listeners;
#       return typeof listeners !== 'undefined' && listeners.length !== 0;
#     }
#
#     const queue = [];
#
#     const track = function (event, data, isInitialPageView) {
#       if (processQueue()) {
#         handleEvent(event, data, isInitialPageView);
#       } else {
#         queue.push({
#           event: event,
#           data: data,
#           isInitialPageView: isInitialPageView
#         });
#       }
#     };
#
#     const handleEvent = function (event, data, isInitialPageView) {
#       if (isInitialPageView) {
#         window.s.referrer = window.trulia.dataLayer.referrer;
#       }
#
#       trulia.dataLayer.listeners.forEach(function (listener) {
#         listener(event, data);
#       });
#     };
#
#     const processQueue = function () {
#       if (listenersDefined()) {
#         if (queue.length) {
#           let queuedData;
#
#           while (queuedData = queue.shift()) {
#             handleEvent(queuedData.event, queuedData.data, queuedData.isInitialPageView);
#           }
#         }
#
#         return true;
#       }
#
#       if (count <= MAX_COUNT) {
#         setTimeout(processQueue, 300);
#         count += 1;
#       }
#
#       return false;
#     };
#
#     if (pageviewPayload) {
#       track('trackState', pageviewPayload, true);
#     }
#
#     window.trulia.dataLayer.track = track;
#   }
#           initTracking({"pageLoad":"1","listingID":"5037770296","maloneID":"2079701553","zPID":"16973448","listingState":"CA","listingCounty":"San Diego","listingCity":"San Diego","listingNeighborhood":"North Park","listingZip":"92104","listingPrice":"558100","listingStatus":"for sale","listingType":"resale","propertyType":"condo","locationLat":"32.74611282348633","locationLon":"-117.14464569091797","rulesApplicable":"1","isthreeDTourAvaliable":"1","ssid":"ssid|pdp:12694","isAuction":"auction_data|0","item":"eight bits of info|show;eightBitItem|condoEtc:Year Built:1976;eightBitItem|condoEtc:Parking:Garage;eightBitItem|condoEtc:Price/Sqft:$647;eightBitItem|condoEtc:HOA:$375/monthly;eightBitItem|condoEtc:Heating:Yes;eightBitItem|condoEtc:Cooling:Yes;eightBitItem|condoEtc:Outdoor:No Info;eightBitItem|condoEtc:Laundry:No Info;","siteSection":"buy","pageType":"pdp","pageDetails":"overview","isZO":"0","similarHomesDisplay":"similarhomes display|0","anonymousUserID":"210911qza98h57f7ibntkao6jcv3m971","automaticTrackState":false,"codebase":"www","testAB":"1255b;1258b;1260d;1274a;1277b;1284b;1291b;1297a;1298b;1300c;1303c;1304b;1305b;1313b;1315b;1317_control;1322_control","truliaUserID":null,"userLoginStatus":"logged out","userStatus":null,"userType":null});
#         </script><script>
#             (function() {
#                 window._pxAppId = 'PXYO6YjwLb';
#                 // Custom parameters
#                 // window._pxParam1 = "<param1>";
#                 var p = document.getElementsByTagName('script')[0],
#                     s = document.createElement('script');
#                 s.async = 1;
#                 s.src = '//client.px-cloud.net/PXYO6YjwLb/main.min.js';
#                 p.parentNode.insertBefore(s, p);
#             }());
#             </script><noscript><div height="1" style="position:fixed;top:0;left:0;display:none" width="1"><img alt="px pixel" src="//collector-PXYO6YjwLb.px-cloud.net/api/v1/collector/noScript.gif?appId=PXYO6YjwLb"/></div></noscript></body></html>

# %% [markdown]
# #### Address:

# %%
soup.find('span', {'data-testid':'home-details-summary-headline'}).get_text()
# Out:
# '1907 Robinson Ave #108'

# %% [markdown]
# #### Bedrooms:

# %%
soup.find('li', {'data-testid':'bed'}).get_text()
# Out:
# '2 Beds'

# %% [markdown]
# #### Bathrooms:

# %%
soup.find('li', {'data-testid':'bath'}).get_text()
# Out:
# '1 Bath'

# %% [markdown]
# #### Sqft:

# %%
soup.find('li', {'data-testid':'floor'}).get_text()
# Out:
# '862 sqft (on 0.51 acres)'

# %% [markdown]
# #### Year built:

# %%
soup.find('div', string='Year Built').findNext('div').get_text()
# Out:
# '1976'

# %% [markdown]
# #### Parking:

# %%
soup.find('div', string='Parking').findNext('div').get_text()
# Out:
# 'Garage'

# %% [markdown]
# #### Pool:

# %%
soup.find('div', string='Pool').findNext('div').get_text()
# Out:
# 'Pool'

# %% [markdown]
# #### Price:

# %%
soup.find('h3', {'data-testid':'on-market-price-details'}).get_text()
# Out:
# '$558,100'

# %% [markdown]
# #### Put all together in page 1

# %%
address = []
bedrooms = []
bathrooms = []
sqft = []
year_built = []
parking = []
pool = []
price = []

# loop through all joined links
for i in url_joined:
    response = requests.get(i)
    
    #create soup object
    soup = BeautifulSoup(response.content, 'html.parser')

    #address
    try:
        address.append(soup.find('span', {'data-testid':'home-details-summary-headline'}).get_text())
    except:
        address.append('')
    
    #bedrooms
    try:
        bedrooms.append(soup.find('li', {'data-testid':'bed'}).get_text())
    except:
        bedrooms.append('')
        
    #bathrooms
    try:
        bathrooms.append(soup.find('li', {'data-testid':'bath'}).get_text())
    except:
        bathrooms.append('')
        
    #sqft
    try:
        sqft.append(soup.find('li', {'data-testid':'floor'}).get_text())
    except:
        sqft.append('')
        
    #year built
    try:
        year_built.append(soup.find('div', string='Year Built').findNext('div').get_text())
    except:
        year_built.append('')
        
     #parking
    try:
        parking.append(soup.find('div', string='Parking').findNext('div').get_text())
    except:
        parking.append('')
        
     #pool
    try:
        pool.append(soup.find('div', string='Pool').findNext('div').get_text())
    except:
        pool.append('')
        
     #price
    try:
        price.append(soup.find('h3', {'data-testid':'on-market-price-details'}).get_text())
    except:
        price.append('')
        
    #creating a dictionary with the results
    output = {'Address': address, 'Bedrooms':bedrooms, 'Bathrooms': bathrooms, 'Area': sqft, 'Year Built': year_built,
             'Parking': parking, 'Pool': pool, 'Price': price}

# %%
output
# Out:
# {'Address': ['1907 Robinson Ave #108',
#   '5250 Lenox Dr',
#   '7720 Tyrolean Rd',
#   '6124 Artisan Way',
#   '12614 Darkwood Rd',
#   '3078 Broadway #107',
#   '12048 Rue Des Amis',
#   '2287 Loring St #1',
#   '4671 Hamilton St #4',
#   '1951 47th St #146',
#   '5170 Clairemont Mesa Blvd #51-18',
#   '10676 Rancho Carmel Dr',
#   '4864 49th St',
#   '303 S 46th St',
#   '4545 Collwood Blvd #20',
#   '3228 44th St #5',
#   '3007 Central Ave',
#   '978 Granger St',
#   '7620 Stalmer St #106',
#   '2737 Lungos Ct',
#   '2930 Naugatuck Ave',
#   '4845 Castle Ave',
#   '3872 Creststone Pl',
#   '236 Payne St',
#   '8190 Califa Ct',
#   '12535 Alcacer Del Sol',
#   '3135 Manos Dr',
#   '328 W Lewis St',
#   '821 Reef Dr',
#   '3573 Chasewood Dr',
#   '1656 Yost Dr',
#   '2615 Nansen Ave',
#   '11445 Spica Dr',
#   '4120 Vivian St',
#   '880 60th St',
#   '5290 Timber Branch Way',
#   '5407 Baja Dr',
#   '4536 Arizona St #4',
#   '8886 La Cartera St',
#   '5850 Camino De La Costa'],
#  'Area': ['862 sqft (on 0.51 acres)',
#   '1,289 sqft',
#   '1,227 sqft',
#   '3,989 sqft',
#   '2,287 sqft',
#   '827 sqft (on 0.74 acres)',
#   '1,622 sqft',
#   '2,312 sqft (on 1.40 acres)',
#   '739 sqft (on 0.30 acres)',
#   '1,466 sqft (on 1.98 acres)',
#   '1,026 sqft (on 0.71 acres)',
#   '1,322 sqft (on 3.68 acres)',
#   '1,115 sqft',
#   '1,045 sqft',
#   '1,120 sqft',
#   '880 sqft',
#   '1,080 sqft (on 0.34 acres)',
#   '1,687 sqft',
#   '1,209 sqft',
#   '1,745 sqft',
#   '1,109 sqft',
#   '1,342 sqft',
#   '1,479 sqft (on 2.58 acres)',
#   '940 sqft',
#   '1,608 sqft',
#   '1,705 sqft',
#   '2,090 sqft',
#   '1,964 sqft (on 0.32 acres)',
#   '1,258 sqft',
#   '1,558 sqft',
#   '1,868 sqft (on 0.26 acres)',
#   '1,457 sqft (on 0.25 acres)',
#   '1,392 sqft',
#   '1,280 sqft',
#   '1,254 sqft',
#   '2,259 sqft',
#   '1,153 sqft',
#   '1,338 sqft',
#   '2,734 sqft',
#   '5,139 sqft'],
#  'Bathrooms': ['1 Bath',
#   '2 Baths',
#   '2 Baths',
#   '5 Baths',
#   '3 Baths',
#   '2 Baths',
#   '3 Baths',
#   '3 Baths',
#   '2 Baths',
#   '2 Baths',
#   '2 Baths',
#   '2 Baths',
#   '1 Bath',
#   '4 Baths',
#   '2 Baths',
#   '2 Baths',
#   '1 Bath',
#   '3 Baths',
#   '2 Baths',
#   '3 Baths',
#   '2 Baths',
#   '2 Baths',
#   '3 Baths',
#   '2 Baths',
#   '2 Baths',
#   '2 Baths',
#   '3 Baths',
#   '3 Baths',
#   '2 Baths',
#   '3 Baths',
#   '3 Baths',
#   '2 Baths',
#   '2 Baths',
#   '1 Bath',
#   '2 Baths',
#   '3 Baths',
#   '2 Baths',
#   '2 Baths',
#   '3 Baths',
#   '5 Baths'],
#  'Bedrooms': ['2 Beds',
#   '4 Beds',
#   '3 Beds',
#   '5 Beds',
#   '4 Beds',
#   '2 Beds',
#   '3 Beds',
#   '3 Beds',
#   '2 Beds',
#   '2 Beds',
#   '2 Beds',
#   '3 Beds',
#   '2 Beds',
#   '3 Beds',
#   '2 Beds',
#   '2 Beds',
#   '3 Beds',
#   '3 Beds',
#   '3 Beds',
#   '5 Beds',
#   '3 Beds',
#   '4 Beds',
#   '3 Beds',
#   '3 Beds',
#   '4 Beds',
#   '3 Beds',
#   '4 Beds',
#   '3 Beds',
#   '3 Beds',
#   '4 Beds',
#   '4 Beds',
#   '3 Beds',
#   '3 Beds',
#   '3 Beds',
#   '4 Beds',
#   '4 Beds',
#   '3 Beds',
#   '3 Beds',
#   '5 Beds',
#   '4 Beds'],
#  'Parking': ['Garage',
#   '2 Car Garage',
#   '1 Car Garage',
#   '2 Car Garage',
#   '3 Car Garage',
#   'Garage',
#   '2 Car Garage',
#   '2 Car Garage',
#   '2 Parking Spaces',
#   'No Info',
#   'Garage',
#   '2 Car Garage',
#   '2 Car Garage',
#   '2 Carport Spaces',
#   'Garage',
#   'Open Parking',
#   'Garage',
#   '2 Car Garage',
#   '1 Car Garage',
#   '2 Car Garage',
#   '2 Car Garage',
#   'Garage',
#   'Garage',
#   'Garage',
#   '2 Car Garage',
#   '2 Car Garage',
#   '2 Car Garage',
#   'Garage',
#   '2 Car Garage',
#   '2 Car Garage',
#   'Garage',
#   '2 Car Garage',
#   '2 Car Garage',
#   '1 Car Garage',
#   '2 Parking Spaces',
#   '3 Car Garage',
#   '2 Car Garage',
#   '2 Car Garage',
#   '2 Car Garage',
#   'Garage'],
#  'Pool': ['Pool',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   '',
#   'Pool',
#   '',
#   'Pool',
#   'No',
#   'No',
#   'No',
#   'Pool',
#   '',
#   'No',
#   'No',
#   'Pool',
#   'No',
#   'No',
#   'No',
#   'Pool',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Pool',
#   'Yes',
#   'Yes'],
#  'Price': ['$558,100',
#   '$460,000',
#   '$798,000',
#   '$2,295,000',
#   '$1,299,000',
#   '$469,000',
#   '$999,000',
#   '$1,099,000',
#   '$499,000',
#   '$169,900',
#   '$436,900',
#   '$749,900',
#   '$899,000',
#   '$579,900',
#   '$375,000',
#   '$380,000',
#   '$600,000',
#   '$749,000',
#   '$515,000',
#   '$649,999',
#   '$965,000',
#   '$749,000',
#   '$1,013,100',
#   '$579,900',
#   '$935,000',
#   '$949,000',
#   '$650,000',
#   '$1,750,000',
#   '$659,000',
#   '$1,100,000',
#   '$1,850,000',
#   '$1,499,000',
#   '$849,000',
#   '$559,000',
#   '$689,900',
#   '$1,650,000',
#   '$845,000',
#   '$699,900',
#   '$1,368,000',
#   '$13,595,000'],
#  'Year Built': ['1976',
#   '1973',
#   '1972',
#   '2018',
#   '1987',
#   '1993',
#   '1984',
#   '1989',
#   '2000',
#   '2014',
#   '1983',
#   '1987',
#   '1951',
#   '1923',
#   '1971',
#   '1981',
#   '1965',
#   '1965',
#   '1987',
#   '1986',
#   '1956',
#   '1946',
#   '1991',
#   '2015',
#   '1972',
#   '1987',
#   '1974',
#   '1929',
#   '1970',
#   '1962',
#   '1965',
#   '1963',
#   '1972',
#   '1951',
#   '1991',
#   '1999',
#   '1960',
#   '1992',
#   '1987',
#   '2016']}

# %%
df = pd.DataFrame(output)

df
# Out:
#                              Address Bedrooms  ...  Pool        Price
# 0             1907 Robinson Ave #108   2 Beds  ...  Pool     $558,100
# 1                      5250 Lenox Dr   4 Beds  ...    No     $460,000
# 2                   7720 Tyrolean Rd   3 Beds  ...   Yes     $798,000
# 3                   6124 Artisan Way   5 Beds  ...    No   $2,295,000
# 4                  12614 Darkwood Rd   4 Beds  ...   Yes   $1,299,000
# 5                 3078 Broadway #107   2 Beds  ...    No     $469,000
# 6                 12048 Rue Des Amis   3 Beds  ...   Yes     $999,000
# 7                  2287 Loring St #1   3 Beds  ...         $1,099,000
# 8                4671 Hamilton St #4   2 Beds  ...  Pool     $499,000
# 9                  1951 47th St #146   2 Beds  ...           $169,900
# 10  5170 Clairemont Mesa Blvd #51-18   2 Beds  ...  Pool     $436,900
# 11            10676 Rancho Carmel Dr   3 Beds  ...    No     $749,900
# 12                      4864 49th St   2 Beds  ...    No     $899,000
# 13                     303 S 46th St   3 Beds  ...    No     $579,900
# 14            4545 Collwood Blvd #20   2 Beds  ...  Pool     $375,000
# 15                   3228 44th St #5   2 Beds  ...           $380,000
# 16                  3007 Central Ave   3 Beds  ...    No     $600,000
# 17                    978 Granger St   3 Beds  ...    No     $749,000
# 18              7620 Stalmer St #106   3 Beds  ...  Pool     $515,000
# 19                    2737 Lungos Ct   5 Beds  ...    No     $649,999
# 20                2930 Naugatuck Ave   3 Beds  ...    No     $965,000
# 21                   4845 Castle Ave   4 Beds  ...    No     $749,000
# 22                3872 Creststone Pl   3 Beds  ...  Pool   $1,013,100
# 23                      236 Payne St   3 Beds  ...    No     $579,900
# 24                    8190 Califa Ct   4 Beds  ...    No     $935,000
# 25             12535 Alcacer Del Sol   3 Beds  ...    No     $949,000
# 26                     3135 Manos Dr   4 Beds  ...    No     $650,000
# 27                    328 W Lewis St   3 Beds  ...    No   $1,750,000
# 28                       821 Reef Dr   3 Beds  ...    No     $659,000
# 29                 3573 Chasewood Dr   4 Beds  ...    No   $1,100,000
# 30                      1656 Yost Dr   4 Beds  ...    No   $1,850,000
# 31                   2615 Nansen Ave   3 Beds  ...   Yes   $1,499,000
# 32                    11445 Spica Dr   3 Beds  ...    No     $849,000
# 33                    4120 Vivian St   3 Beds  ...    No     $559,000
# 34                       880 60th St   4 Beds  ...    No     $689,900
# 35            5290 Timber Branch Way   4 Beds  ...    No   $1,650,000
# 36                      5407 Baja Dr   3 Beds  ...    No     $845,000
# 37                4536 Arizona St #4   3 Beds  ...  Pool     $699,900
# 38                8886 La Cartera St   5 Beds  ...   Yes   $1,368,000
# 39           5850 Camino De La Costa   4 Beds  ...   Yes  $13,595,000
#
# [40 rows x 8 columns]

# %% [markdown]
# ## Scraping Multiple Pages - San Diego

# %%
address = []
bedrooms = []
bathrooms = []
sqft = []
year_built = []
parking = []
pool = []
price = []

# Url part I
url_1 = 'https://www.trulia.com'

for i in range(1, 26):
    
    #website
    www = 'https://www.trulia.com/CA/San_Diego/' +str(i) +'_p/'
    
    #requests
    response = requests.get(www)
    
    # soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    #result container
    result_container = soup.find_all('li', {'class':'SearchResultsList__WideCell-b7y9ki-2'})
    
    #update results
    results_update = []
    
    # only results with attribute 'data-testeid'
    for r in result_container:
        if r.has_attr('data-testid'):
            results_update.append(r)
        
    #relative url
    relative_url = []
    
    #loop through results
    for i in results_update:
        for j in i.find_all('div', {'data-testid':'property-card-details'}):
            relative_url.append(j.find('a').get('href'))
            
    #empty list url_joined
    url_joined = []

    for i in relative_url:
        url_joined.append(urllib.parse.urljoin(url_1, i))
        
       
    # loop through all joined links
    for i in url_joined:
        response = requests.get(i)

        #create soup object
        soup = BeautifulSoup(response.content, 'html.parser')

        #address
        try:
            address.append(soup.find('span', {'data-testid':'home-details-summary-headline'}).get_text())
        except:
            address.append('')

        #bedrooms
        try:
            bedrooms.append(soup.find('li', {'data-testid':'bed'}).get_text())
        except:
            bedrooms.append('')

        #bathrooms
        try:
            bathrooms.append(soup.find('li', {'data-testid':'bath'}).get_text())
        except:
            bathrooms.append('')

        #sqft
        try:
            sqft.append(soup.find('li', {'data-testid':'floor'}).get_text())
        except:
            sqft.append('')

        #year built
        try:
            year_built.append(soup.find('div', string='Year Built').findNext('div').get_text())
        except:
            year_built.append('')

         #parking
        try:
            parking.append(soup.find('div', string='Parking').findNext('div').get_text())
        except:
            parking.append('')

         #pool
        try:
            pool.append(soup.find('div', string='Pool').findNext('div').get_text())
        except:
            pool.append('')

         #price
        try:
            price.append(soup.find('h3', {'data-testid':'on-market-price-details'}).get_text())
        except:
            price.append('')

        #creating a dictionary with the results
        output = {'Address': address, 'Bedrooms':bedrooms, 'Bathrooms': bathrooms, 'Area': sqft, 'Year Built': year_built,
                 'Parking': parking, 'Pool': pool, 'Price': price}

# %%
df = pd.DataFrame(output)
df
# Out:
#                            Address Bedrooms  ...  Pool       Price
# 0           1907 Robinson Ave #108   2 Beds  ...  Pool    $558,100
# 1                    5250 Lenox Dr   4 Beds  ...    No    $460,000
# 2                 7720 Tyrolean Rd   3 Beds  ...   Yes    $798,000
# 3                 6124 Artisan Way   5 Beds  ...    No  $2,295,000
# 4                12614 Darkwood Rd   4 Beds  ...   Yes  $1,299,000
# ..                             ...      ...  ...   ...         ...
# 995                804 Ensenada Ct   5 Beds  ...    No  $2,399,999
# 996                 3035 Locust St   5 Beds  ...    No  $1,445,000
# 997  18840 Caminito Cantilena #107   2 Beds  ...  Pool    $499,888
# 998       4350 Mount Abernathy Ave   5 Beds  ...    No  $1,350,000
# 999              2665 5th Ave #302   2 Beds  ...        $1,210,000
#
# [1000 rows x 8 columns]

# %%
df['Location'] = 'San Diego'
df
# Out:
#                            Address Bedrooms  ...       Price   Location
# 0           1907 Robinson Ave #108   2 Beds  ...    $558,100  San Diego
# 1                    5250 Lenox Dr   4 Beds  ...    $460,000  San Diego
# 2                 7720 Tyrolean Rd   3 Beds  ...    $798,000  San Diego
# 3                 6124 Artisan Way   5 Beds  ...  $2,295,000  San Diego
# 4                12614 Darkwood Rd   4 Beds  ...  $1,299,000  San Diego
# ..                             ...      ...  ...         ...        ...
# 995                804 Ensenada Ct   5 Beds  ...  $2,399,999  San Diego
# 996                 3035 Locust St   5 Beds  ...  $1,445,000  San Diego
# 997  18840 Caminito Cantilena #107   2 Beds  ...    $499,888  San Diego
# 998       4350 Mount Abernathy Ave   5 Beds  ...  $1,350,000  San Diego
# 999              2665 5th Ave #302   2 Beds  ...  $1,210,000  San Diego
#
# [1000 rows x 9 columns]

# %%
df.to_csv('df_san_diego.csv', index=False)
